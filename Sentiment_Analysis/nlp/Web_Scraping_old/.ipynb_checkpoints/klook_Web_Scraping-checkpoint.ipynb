# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import bs4
import pandas as pd

# %%
service = Service(r'C:\Users\HP Pavilian\OneDrive\Desktop\Sentiment_Analysis\nlp\Web_Scraping\chromedriver\chromedriver.exe')
driver = webdriver.Chrome(service=service)

# %%
driver.get('https://th.hotels.com/Hotel-Search?startDate=2024-11-26&endDate=2024-12-10&regionId=6056227&adults=2&amenities=OCEAN_VIEW&destination=Pattaya%2C%20Chonburi%20Province%2C%20Thailand&theme=&userIntent=&semdtl=&useRewards=false&sort=RECOMMENDED')

# %%
driver.execute_script("document.body.style.zoom='100%'")

# %%
#bad_dataSize = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')

# %%
data = driver.page_source

# %%
soup = bs4.BeautifulSoup(data)

# %%
len(soup.find_all('h3',{'class':'uitk-heading uitk-heading-5 overflow-wrap uitk-layout-grid-item uitk-layout-grid-item-has-row-start'}))
# Out:
# 96

# %%
all_hotels_name = soup.find_all('h3',{'class':'uitk-heading uitk-heading-5 overflow-wrap uitk-layout-grid-item uitk-layout-grid-item-has-row-start'})

# %%
all_hotels_name_list = []
for hotels_name in all_hotels_name:
    all_hotels_name_list.append(hotels_name.text)

df_hotels = pd.DataFrame(all_hotels_name_list)
print(df_hotels.head())
# Out:
#                                         0
# 0              โรงแรมรอยัล คลิฟ บีช พัทยา
# 1          รอยัล วิง สวีท แอนด์ สปา พัทยา
# 2                             อมารี พัทยา
# 3                       โอโซ่ นอร์ธ พัทยา
# 4  ฮอลิเดย์อินน์ พัทยา เครือโรงแรมไอเอชจี

# %%
len(soup.find_all('div',{'class':'uitk-layout-flex uitk-layout-flex-align-items-center uitk-layout-flex-gap-one'}))
# Out:
# 262

# %%
all_rate = soup.find_all('div',{'class':'uitk-layout-flex uitk-layout-flex-align-items-center uitk-layout-flex-gap-one'})

# %%
for rate in all_rate:
    print(rate.text)
    print()
# Out:
# 8.48.4 เต็ม 10ดีมากดีมาก1,027 รีวิว(1,027 รีวิว)
#
# ดีมากดีมาก
#
# 1,027 รีวิว(1,027 รีวิว)
#
# 9.89.8 เต็ม 10ไร้ที่ติไร้ที่ติ109 รีวิว(109 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 109 รีวิว(109 รีวิว)
#
# 8.88.8 เต็ม 10ดีเลิศดีเลิศ1,032 รีวิว(1,032 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 1,032 รีวิว(1,032 รีวิว)
#
# 9.29.2 เต็ม 10ยอดเยี่ยมยอดเยี่ยม452 รีวิว(452 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 452 รีวิว(452 รีวิว)
#
# 9.29.2 เต็ม 10ยอดเยี่ยมยอดเยี่ยม1,045 รีวิว(1,045 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 1,045 รีวิว(1,045 รีวิว)
#
# 8.28.2 เต็ม 10ดีมากดีมาก95 รีวิว(95 รีวิว)
#
# ดีมากดีมาก
#
# 95 รีวิว(95 รีวิว)
#
# 9.09.0 เต็ม 10ยอดเยี่ยมยอดเยี่ยม643 รีวิว(643 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 643 รีวิว(643 รีวิว)
#
# 1010 เต็ม 10ไร้ที่ติไร้ที่ติ1 รีวิว(1 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 1 รีวิว(1 รีวิว)
#
# 8.88.8 เต็ม 10ดีเลิศดีเลิศ1,009 รีวิว(1,009 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 1,009 รีวิว(1,009 รีวิว)
#
# 8.08.0 เต็ม 10ดีมากดีมาก9 รีวิว(9 รีวิว)
#
# ดีมากดีมาก
#
# 9 รีวิว(9 รีวิว)
#
# 7.87.8 เต็ม 10ดีดี142 รีวิว(142 รีวิว)
#
# ดีดี
#
# 142 รีวิว(142 รีวิว)
#
# 8.48.4 เต็ม 10ดีมากดีมาก1,027 รีวิว(1,027 รีวิว)
#
# ดีมากดีมาก
#
# 1,027 รีวิว(1,027 รีวิว)
#
# 7.67.6 เต็ม 10ดีดี211 รีวิว(211 รีวิว)
#
# ดีดี
#
# 211 รีวิว(211 รีวิว)
#
# 7.27.2 เต็ม 10ดีดี365 รีวิว(365 รีวิว)
#
# ดีดี
#
# 365 รีวิว(365 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ161 รีวิว(161 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 161 รีวิว(161 รีวิว)
#
# 7.47.4 เต็ม 10ดีดี3 รีวิว(3 รีวิว)
#
# ดีดี
#
# 3 รีวิว(3 รีวิว)
#
# 7.07.0 เต็ม 10ดีดี121 รีวิว(121 รีวิว)
#
# ดีดี
#
# 121 รีวิว(121 รีวิว)
#
# 8.28.2 เต็ม 10ดีมากดีมาก18 รีวิวจากภายนอก(18 รีวิวจากภายนอก)
#
# ดีมากดีมาก
#
# 18 รีวิวจากภายนอก(18 รีวิวจากภายนอก)
#
# 8.48.4 เต็ม 10ดีมากดีมาก42 รีวิว(42 รีวิว)
#
# ดีมากดีมาก
#
# 42 รีวิว(42 รีวิว)
#
# 8.08.0 เต็ม 10ดีมากดีมาก160 รีวิว(160 รีวิว)
#
# ดีมากดีมาก
#
# 160 รีวิว(160 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ197 รีวิว(197 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 197 รีวิว(197 รีวิว)
#
# 9.89.8 เต็ม 10ไร้ที่ติไร้ที่ติ109 รีวิว(109 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 109 รีวิว(109 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ93 รีวิว(93 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 93 รีวิว(93 รีวิว)
#
# 7.47.4 เต็ม 10ดีดี157 รีวิว(157 รีวิว)
#
# ดีดี
#
# 157 รีวิว(157 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ1,015 รีวิว(1,015 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 1,015 รีวิว(1,015 รีวิว)
#
# 8.08.0 เต็ม 10ดีมากดีมาก1 รีวิว(1 รีวิว)
#
# ดีมากดีมาก
#
# 1 รีวิว(1 รีวิว)
#
# 9.29.2 เต็ม 10ยอดเยี่ยมยอดเยี่ยม400 รีวิว(400 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 400 รีวิว(400 รีวิว)
#
# 6.86.8 เต็ม 10125 รีวิว(125 รีวิว)
#
# 125 รีวิว(125 รีวิว)
#
# 6.06.0 เต็ม 102 รีวิว(2 รีวิว)
#
# 2 รีวิว(2 รีวิว)
#
# 1010 เต็ม 10ไร้ที่ติไร้ที่ติ1 รีวิว(1 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 1 รีวิว(1 รีวิว)
#
# 9.09.0 เต็ม 10ยอดเยี่ยมยอดเยี่ยม602 รีวิว(602 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 602 รีวิว(602 รีวิว)
#
# 6.66.6 เต็ม 1095 รีวิว(95 รีวิว)
#
# 95 รีวิว(95 รีวิว)
#
# 9.49.4 เต็ม 10ไร้ที่ติไร้ที่ติ588 รีวิว(588 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 588 รีวิว(588 รีวิว)
#
# 7.47.4 เต็ม 10ดีดี35 รีวิว(35 รีวิว)
#
# ดีดี
#
# 35 รีวิว(35 รีวิว)
#
# 7.87.8 เต็ม 10ดีดี318 รีวิว(318 รีวิว)
#
# ดีดี
#
# 318 รีวิว(318 รีวิว)
#
# 1010 เต็ม 10ไร้ที่ติไร้ที่ติ1 รีวิว(1 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 1 รีวิว(1 รีวิว)
#
# 8.88.8 เต็ม 10ดีเลิศดีเลิศ545 รีวิว(545 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 545 รีวิว(545 รีวิว)
#
# 8.08.0 เต็ม 10ดีมากดีมาก22 รีวิว(22 รีวิว)
#
# ดีมากดีมาก
#
# 22 รีวิว(22 รีวิว)
#
# 8.28.2 เต็ม 10ดีมากดีมาก68 รีวิว(68 รีวิว)
#
# ดีมากดีมาก
#
# 68 รีวิว(68 รีวิว)
#
# 9.09.0 เต็ม 10ยอดเยี่ยมยอดเยี่ยม265 รีวิว(265 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 265 รีวิว(265 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ10 รีวิว(10 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 10 รีวิว(10 รีวิว)
#
# 9.69.6 เต็ม 10ไร้ที่ติไร้ที่ติ58 รีวิว(58 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 58 รีวิว(58 รีวิว)
#
# 8.08.0 เต็ม 10ดีมากดีมาก49 รีวิว(49 รีวิว)
#
# ดีมากดีมาก
#
# 49 รีวิว(49 รีวิว)
#
# 8.88.8 เต็ม 10ดีเลิศดีเลิศ33 รีวิว(33 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 33 รีวิว(33 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ69 รีวิว(69 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 69 รีวิว(69 รีวิว)
#
# 7.87.8 เต็ม 10ดีดี82 รีวิว(82 รีวิว)
#
# ดีดี
#
# 82 รีวิว(82 รีวิว)
#
# 8.28.2 เต็ม 10ดีมากดีมาก31 รีวิว(31 รีวิว)
#
# ดีมากดีมาก
#
# 31 รีวิว(31 รีวิว)
#
# 9.29.2 เต็ม 10ยอดเยี่ยมยอดเยี่ยม38 รีวิวจากภายนอก(38 รีวิวจากภายนอก)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 38 รีวิวจากภายนอก(38 รีวิวจากภายนอก)
#
# 8.48.4 เต็ม 10ดีมากดีมาก98 รีวิว(98 รีวิว)
#
# ดีมากดีมาก
#
# 98 รีวิว(98 รีวิว)
#
# 8.48.4 เต็ม 10ดีมากดีมาก18 รีวิว(18 รีวิว)
#
# ดีมากดีมาก
#
# 18 รีวิว(18 รีวิว)
#
# 5.05.0 เต็ม 1010 รีวิว(10 รีวิว)
#
# 10 รีวิว(10 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ74 รีวิว(74 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 74 รีวิว(74 รีวิว)
#
# 9.49.4 เต็ม 10ไร้ที่ติไร้ที่ติ112 รีวิว(112 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 112 รีวิว(112 รีวิว)
#
# 8.88.8 เต็ม 10ดีเลิศดีเลิศ307 รีวิว(307 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 307 รีวิว(307 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ2 รีวิวจากภายนอก(2 รีวิวจากภายนอก)
#
# ดีเลิศดีเลิศ
#
# 2 รีวิวจากภายนอก(2 รีวิวจากภายนอก)
#
# 8.08.0 เต็ม 10ดีมากดีมาก1 รีวิว(1 รีวิว)
#
# ดีมากดีมาก
#
# 1 รีวิว(1 รีวิว)
#
# 8.48.4 เต็ม 10ดีมากดีมาก16 รีวิว(16 รีวิว)
#
# ดีมากดีมาก
#
# 16 รีวิว(16 รีวิว)
#
# 8.28.2 เต็ม 10ดีมากดีมาก1,021 รีวิว(1,021 รีวิว)
#
# ดีมากดีมาก
#
# 1,021 รีวิว(1,021 รีวิว)
#
# 9.09.0 เต็ม 10ยอดเยี่ยมยอดเยี่ยม1,046 รีวิว(1,046 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 1,046 รีวิว(1,046 รีวิว)
#
# 8.28.2 เต็ม 10ดีมากดีมาก1,027 รีวิว(1,027 รีวิว)
#
# ดีมากดีมาก
#
# 1,027 รีวิว(1,027 รีวิว)
#
# 8.28.2 เต็ม 10ดีมากดีมาก1,027 รีวิว(1,027 รีวิว)
#
# ดีมากดีมาก
#
# 1,027 รีวิว(1,027 รีวิว)
#
# 7.87.8 เต็ม 10ดีดี1,039 รีวิว(1,039 รีวิว)
#
# ดีดี
#
# 1,039 รีวิว(1,039 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ104 รีวิว(104 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 104 รีวิว(104 รีวิว)
#
# 8.08.0 เต็ม 10ดีมากดีมาก319 รีวิว(319 รีวิว)
#
# ดีมากดีมาก
#
# 319 รีวิว(319 รีวิว)
#
# 8.48.4 เต็ม 10ดีมากดีมาก164 รีวิว(164 รีวิว)
#
# ดีมากดีมาก
#
# 164 รีวิว(164 รีวิว)
#
# 6.86.8 เต็ม 1041 รีวิว(41 รีวิว)
#
# 41 รีวิว(41 รีวิว)
#
# 8.48.4 เต็ม 10ดีมากดีมาก102 รีวิว(102 รีวิว)
#
# ดีมากดีมาก
#
# 102 รีวิว(102 รีวิว)
#
# 9.29.2 เต็ม 10ยอดเยี่ยมยอดเยี่ยม25 รีวิว(25 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 25 รีวิว(25 รีวิว)
#
# 9.09.0 เต็ม 10ยอดเยี่ยมยอดเยี่ยม4 รีวิว(4 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 4 รีวิว(4 รีวิว)
#
# 9.09.0 เต็ม 10ยอดเยี่ยมยอดเยี่ยม278 รีวิว(278 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 278 รีวิว(278 รีวิว)
#
# 8.48.4 เต็ม 10ดีมากดีมาก5 รีวิว(5 รีวิว)
#
# ดีมากดีมาก
#
# 5 รีวิว(5 รีวิว)
#
# 8.48.4 เต็ม 10ดีมากดีมาก5 รีวิว(5 รีวิว)
#
# ดีมากดีมาก
#
# 5 รีวิว(5 รีวิว)
#
# 9.09.0 เต็ม 10ยอดเยี่ยมยอดเยี่ยม195 รีวิว(195 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 195 รีวิว(195 รีวิว)
#
# 1010 เต็ม 10ไร้ที่ติไร้ที่ติ6 รีวิว(6 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 6 รีวิว(6 รีวิว)
#
# 7.27.2 เต็ม 10ดีดี63 รีวิว(63 รีวิว)
#
# ดีดี
#
# 63 รีวิว(63 รีวิว)
#
# 9.29.2 เต็ม 10ยอดเยี่ยมยอดเยี่ยม5 รีวิวจากภายนอก(5 รีวิวจากภายนอก)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 5 รีวิวจากภายนอก(5 รีวิวจากภายนอก)
#
# 6.46.4 เต็ม 10108 รีวิว(108 รีวิว)
#
# 108 รีวิว(108 รีวิว)
#
# 7.07.0 เต็ม 10ดีดี19 รีวิว(19 รีวิว)
#
# ดีดี
#
# 19 รีวิว(19 รีวิว)
#
# 7.87.8 เต็ม 10ดีดี3 รีวิวจากภายนอก(3 รีวิวจากภายนอก)
#
# ดีดี
#
# 3 รีวิวจากภายนอก(3 รีวิวจากภายนอก)
#
# 6.06.0 เต็ม 105 รีวิว(5 รีวิว)
#
# 5 รีวิว(5 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ515 รีวิว(515 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 515 รีวิว(515 รีวิว)
#
# 7.47.4 เต็ม 10ดีดี3 รีวิว(3 รีวิว)
#
# ดีดี
#
# 3 รีวิว(3 รีวิว)
#
# 8.28.2 เต็ม 10ดีมากดีมาก71 รีวิว(71 รีวิว)
#
# ดีมากดีมาก
#
# 71 รีวิว(71 รีวิว)
#
# 8.08.0 เต็ม 10ดีมากดีมาก4 รีวิว(4 รีวิว)
#
# ดีมากดีมาก
#
# 4 รีวิว(4 รีวิว)
#
# 7.07.0 เต็ม 10ดีดี9 รีวิว(9 รีวิว)
#
# ดีดี
#
# 9 รีวิว(9 รีวิว)
#
# 8.68.6 เต็ม 10ดีเลิศดีเลิศ9 รีวิว(9 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 9 รีวิว(9 รีวิว)
#
# 8.88.8 เต็ม 10ดีเลิศดีเลิศ169 รีวิว(169 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 169 รีวิว(169 รีวิว)
#
# 9.69.6 เต็ม 10ไร้ที่ติไร้ที่ติ18 รีวิว(18 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 18 รีวิว(18 รีวิว)
#
# 8.48.4 เต็ม 10ดีมากดีมาก14 รีวิว(14 รีวิว)
#
# ดีมากดีมาก
#
# 14 รีวิว(14 รีวิว)
#
# 2.02.0 เต็ม 101 รีวิว(1 รีวิว)
#
# 1 รีวิว(1 รีวิว)

# %%
len(soup.find_all('div',{'class':'uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden'}))
# Out:
# 107

# %%
all_price = soup.find_all('div',{'class':'uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden'})

# %%
for price in all_price:
    print(price.text)
    print()
# Out:
# เข้าสู่ระบบหรือสร้างบัญชี
#
# ราคาเดิมคือ ฿6,973
#
# ราคาปัจจุบันคือ ฿4,909
#
# ราคาเดิมคือ ฿13,671
#
# ราคาปัจจุบันคือ ฿9,625
#
# ราคาเดิมคือ ฿6,671
#
# ราคาปัจจุบันคือ ฿5,337
#
# ราคาปัจจุบันคือ ฿3,702
#
# ราคาปัจจุบันคือ ฿5,256
#
# ราคาปัจจุบันคือ ฿4,278
#
# ราคาปัจจุบันคือ ฿55,834
#
# ราคาเดิมคือ ฿14,589
#
# ราคาปัจจุบันคือ ฿13,003
#
# ราคาเดิมคือ ฿5,102
#
# ราคาปัจจุบันคือ ฿4,285
#
# ราคาเดิมคือ ฿4,509
#
# ราคาปัจจุบันคือ ฿3,156
#
# ราคาเดิมคือ ฿6,577
#
# ราคาปัจจุบันคือ ฿5,839
#
# ราคาเดิมคือ ฿6,973
#
# ราคาปัจจุบันคือ ฿4,909
#
# ราคาเดิมคือ ฿3,350
#
# ราคาปัจจุบันคือ ฿2,847
#
# ราคาเดิมคือ ฿4,485
#
# ราคาปัจจุบันคือ ฿2,915
#
# ราคาเดิมคือ ฿13,429
#
# ราคาปัจจุบันคือ ฿10,743
#
# ราคาเดิมคือ ฿2,460
#
# ราคาปัจจุบันคือ ฿2,214
#
# ราคาเดิมคือ ฿4,078
#
# ราคาปัจจุบันคือ ฿1,754
#
# ราคาปัจจุบันคือ ฿2,321
#
# ราคาปัจจุบันคือ ฿7,023
#
# ราคาเดิมคือ ฿3,823
#
# ราคาปัจจุบันคือ ฿1,797
#
# ราคาปัจจุบันคือ ฿5,357
#
# ราคาเดิมคือ ฿13,671
#
# ราคาปัจจุบันคือ ฿9,625
#
# ราคาปัจจุบันคือ ฿4,876
#
# ราคาเดิมคือ ฿4,788
#
# ราคาปัจจุบันคือ ฿3,112
#
# ราคาปัจจุบันคือ ฿7,659
#
# ราคาปัจจุบันคือ ฿16,131
#
# ราคาเดิมคือ ฿5,289
#
# ราคาปัจจุบันคือ ฿3,564
#
# ราคาเดิมคือ ฿13,832
#
# ราคาปัจจุบันคือ ฿6,239
#
# ราคาเดิมคือ ฿17,053
#
# ราคาปัจจุบันคือ ฿12,960
#
# ราคาเดิมคือ ฿23,967
#
# ราคาปัจจุบันคือ ฿21,362
#
# ราคาเดิมคือ ฿16,883
#
# ราคาปัจจุบันคือ ฿11,886
#
# ราคาเดิมคือ ฿15,702
#
# ราคาปัจจุบันคือ ฿13,917
#
# ราคาเดิมคือ ฿8,681
#
# ราคาปัจจุบันคือ ฿6,334
#
# ราคาเดิมคือ ฿5,722
#
# ราคาปัจจุบันคือ ฿1,919
#
# ราคาเดิมคือ ฿19,153
#
# ราคาปัจจุบันคือ ฿16,854
#
# ราคาเดิมคือ ฿3,596
#
# ราคาปัจจุบันคือ ฿2,337
#
# ราคาเดิมคือ ฿6,430
#
# ราคาปัจจุบันคือ ฿4,351
#
# ราคาเดิมคือ ฿3,604
#
# ราคาปัจจุบันคือ ฿3,475
#
# ราคาปัจจุบันคือ ฿5,830
#
# ราคาเดิมคือ ฿9,306
#
# ราคาปัจจุบันคือ ฿7,817
#
# ราคาเดิมคือ ฿6,703
#
# ราคาปัจจุบันคือ ฿4,022
#
# ราคาปัจจุบันคือ ฿9,490
#
# ราคาเดิมคือ ฿4,091
#
# ราคาปัจจุบันคือ ฿2,880
#
# ราคาปัจจุบันคือ ฿40,150
#
# ราคาปัจจุบันคือ ฿22,843
#
# ราคาเดิมคือ ฿3,972
#
# ราคาปัจจุบันคือ ฿3,749
#
# ราคาเดิมคือ ฿7,861
#
# ราคาปัจจุบันคือ ฿4,953
#
# ราคาเดิมคือ ฿23,304
#
# ราคาปัจจุบันคือ ฿8,389
#
# ราคาเดิมคือ ฿1,556
#
# ราคาปัจจุบันคือ ฿1,416
#
# ราคาเดิมคือ ฿4,510
#
# ราคาปัจจุบันคือ ฿2,763
#
# ราคาเดิมคือ ฿4,293
#
# ราคาปัจจุบันคือ ฿3,434
#
# ราคาเดิมคือ ฿1,881
#
# ราคาปัจจุบันคือ ฿1,681
#
# ราคาปัจจุบันคือ ฿2,536
#
# ราคาเดิมคือ ฿1,359
#
# ราคาปัจจุบันคือ ฿1,196
#
# ราคาเดิมคือ ฿1,784
#
# ราคาปัจจุบันคือ ฿1,606
#
# ราคาเดิมคือ ฿1,094
#
# ราคาปัจจุบันคือ ฿975
#
# ราคาเดิมคือ ฿5,197
#
# ราคาปัจจุบันคือ ฿4,677
#
# ราคาเดิมคือ ฿7,429
#
# ราคาปัจจุบันคือ ฿5,810
#
# ราคาปัจจุบันคือ ฿2,124
#
# ราคาเดิมคือ ฿2,373
#
# ราคาปัจจุบันคือ ฿1,779
#
# ราคาเดิมคือ ฿2,310
#
# ราคาปัจจุบันคือ ฿1,524
