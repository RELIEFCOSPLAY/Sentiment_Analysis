# %% [markdown]
# # Lazada Web Scraping

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import bs4
import pandas as pd
import re

# %% [markdown]
# ### Service and Driver

# %%
service = Service(r'C:\Users\User\Desktop\ETLPY\Sentiment_Analysis\nlp\Web_Scraping\chromedriver\chromedriver.exe')
driver = webdriver.Chrome(service=service)

# %% [markdown]
# ### Url Lazada

# %%
driver.get('https://www.lazada.co.th/')

# %% [markdown]
# ### Find Search bar

# %%
search = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div[2]/div/form/div/div[1]/input[1]')

# %%
search.send_keys('ชีสทาร์ตสตอเบอรี่')

# %%
search.send_keys(Keys.ENTER)

# %% [markdown]
# ### Find Content Box

# %%
Content_Box = driver.find_element(By.XPATH, '/html/body/div[4]/div/div[2]/div[1]/div/div[1]/div[2]/div[1]')

# %%
Content_Box.click()

# %% [markdown]
# ### Zoom

# %%
driver.execute_script("document.body.style.zoom='20%'")

# %% [markdown]
# ### Page Source Data

# %%
data = driver.page_source

# %%
soup = bs4.BeautifulSoup(data)

# %% [markdown]
# ### Content data

# %% [markdown]
# all_content = soup.find_all('div',{'class':'content'})

# %% [markdown]
# all_content_list = []
# for content in all_content:
#     all_content_list.append(content.text)
#
# df_content = pd.DataFrame(all_content_list)
# print(df_content)

# %% [markdown]
# for content in all_content:
#     print(content.text)
#     print()

# %% [markdown]
# ### Star data

# %% [markdown]
# rating_containers = driver.find_elements(By.CSS_SELECTOR, "div.container-star.starCtn.left")

# %% [markdown]
# ratings = []
#
# # Iterate through each container to count stars
# for container in rating_containers:
#     try:
#         stars = container.find_elements(By.CSS_SELECTOR, "img.star")  # Locate stars within the container
#         if stars:
#             ratings.append(len(stars))  # Count the stars and append the count
#         else:
#             ratings.append("none")  # Add "none" if no stars are found
#     except Exception as e:
#         ratings.append(f"error: {e}")  # Handle any potential errors
#
# # Display the ratings
# for index, rating in enumerate(ratings, start=1):
#     print(f"รายการที่ {index}: {rating} ดาว")

# %% [markdown]
# ### Loop Test

# %% [markdown]
# import re
#
# # เก็บข้อมูลทั้งหมด
# all_content_list = []
# ratings = []
#
# # เริ่มต้น While Loop
# while True:
#     try:
#         # ดึงข้อมูลเนื้อหาจาก div ที่มีคลาส 'content'
#         all_content = soup.find_all('div', {'class': 'content'})
#         temp_content = []  # ใช้เก็บข้อมูล content ในรอบนี้
#         for content in all_content:
#             text = content.text.strip()  # ตัดช่องว่างก่อนและหลังข้อความ
#             # ตรวจสอบข้อความที่ไม่ต้องการ
#             if not re.search(r"^\d+\.\d+/\d+ Ratings\d+$", text):
#                 temp_content.append(text)  # เก็บข้อความที่ไม่ตรงกับรูปแบบ
#
#         # เก็บข้อมูล Rating จาก container-star
#         rating_containers = driver.find_elements(By.CSS_SELECTOR, "div.container-star.starCtn.left")
#         temp_ratings = []  # ใช้เก็บข้อมูล ratings ในรอบนี้
#         for container in rating_containers:
#             try:
#                 stars = container.find_elements(By.CSS_SELECTOR, "img.star")
#                 if stars:
#                     temp_ratings.append(len(stars))  # นับจำนวนดาว
#                 else:
#                     temp_ratings.append("none")  # กรณีไม่มีดาว
#             except Exception as e:
#                 temp_ratings.append(f"error: {e}")  # หากมีข้อผิดพลาด
#
#         # ตรวจสอบว่าข้อมูล Content และ Ratings มีจำนวนเท่ากัน
#         if len(temp_content) != len(temp_ratings):
#             print("จำนวน Content และ Ratings ไม่ตรงกัน เติมค่า 'none'")
#             # เติมค่า "none" ให้ข้อมูลที่ขาดหาย
#             while len(temp_content) > len(temp_ratings):
#                 temp_ratings.append("none")
#             while len(temp_ratings) > len(temp_content):
#                 temp_content.append("none")
#
#         # เพิ่มข้อมูลเข้าในรายการหลัก
#         all_content_list.extend(temp_content)
#         ratings.extend(temp_ratings)
#
#         # สร้าง DataFrame จากข้อมูล
#         df_content = pd.DataFrame({'Content': all_content_list, 'Rating': ratings})
#         print(df_content)
#
#         # คลิกปุ่ม Next
#         nextButton = driver.find_element(By.XPATH, '/html/body/div[5]/div/div[10]/div[1]/div[2]/div/div/div/div[3]/div[2]/div/button[2]')
#         nextButton.click()
#
#          # ดึงข้อมูล HTML ปัจจุบันจาก Selenium
#         data = driver.page_source
#         soup = bs4.BeautifulSoup(data)
#
#         # รอให้หน้าโหลดข้อมูลใหม่ก่อนเริ่ม Loop ใหม่
#         time.sleep(5)  # รอ 5 วินาที (หรือปรับเวลาตามความเหมาะสม)
#
#     except Exception as e:
#         print("เกิดข้อผิดพลาด:", e)
#         break  # หยุด Loop หากเกิดข้อผิดพลาด เช่น ไม่มีปุ่มถัดไป
#
# # # บันทึกลงไฟล์ Excel
# # df_content.to_excel('content_ratings_filtered.xlsx', index=False)
# # print("บันทึกข้อมูลเรียบร้อยใน content_ratings_filtered.xlsx")

# %% [markdown]
# df_content = pd.DataFrame(all_content_list, columns=['Content'])

# %% [markdown]
# df_content.to_excel(r'C:\Users\User\Desktop\ETLPY\Sentiment_Analysis\nlp\Web_Scraping\lazada_data_case3.xlsx', index=False)

# %%
import re

# เก็บข้อมูลทั้งหมด
all_content_list = []
ratings = []
all_name_list = []
date_list = []
like_list = []

# เริ่มต้น While Loop
while True:
    try:
        # ดึงข้อมูลเนื้อหาจาก div ที่มีคลาส 'content'
        all_content = soup.find_all('div', {'class': 'content'})
        temp_content = []  # ใช้เก็บข้อมูล content ในรอบนี้
        for content in all_content:
            text = content.text.strip()  # ตัดช่องว่างก่อนและหลังข้อความ
            # ตรวจสอบข้อความที่ไม่ต้องการ
            if not re.search(r"^\d+\.\d+/\d+ Ratings\d+$", text):
                temp_content.append(text)  # เก็บข้อความที่ไม่ตรงกับรูปแบบ
        
        # ดึงข้อมูล Rating จาก container-star
        rating_containers = driver.find_elements(By.CSS_SELECTOR, "div.container-star.starCtn.left")
        temp_ratings = []  # ใช้เก็บข้อมูล ratings ในรอบนี้
        for container in rating_containers:
            try:
                stars = container.find_elements(By.CSS_SELECTOR, "img.star")
                if stars:
                    temp_ratings.append(len(stars))  # นับจำนวนดาว
                else:
                    temp_ratings.append("none")  # กรณีไม่มีดาว
            except Exception as e:
                temp_ratings.append(f"error: {e}")  # หากมีข้อผิดพลาด

        # ดึงข้อมูลชื่อจาก middle
        all_name = soup.find_all('div', {'class': 'middle'})
        temp_names = []
        for name in all_name:
            span = name.find('span')  # ค้นหาแท็ก span ภายใน div ที่เลือกไว้
            if span:
                temp_names.append(span.text.strip())  # ดึงข้อความและตัดช่องว่าง

        # ดึงข้อมูลวันที่จาก title right
        all_date = soup.find_all('span', {'class': 'title right'})
        temp_dates = []
        for date in all_date:
            temp_dates.append(date.text.strip())  # ดึงข้อความและลบช่องว่าง

        # ดึงข้อมูล like จาก left-content
        all_like = soup.find_all('span', {'class': 'left-content'})
        temp_likes = []
        for like in all_like:
            span = like.find('span')  # ค้นหาแท็ก span ที่อยู่ภายใน
            if span:
                temp_likes.append(span.text.strip())  # ดึงข้อความและตัดช่องว่าง

        # ตรวจสอบว่าข้อมูล Content และ Ratings มีจำนวนเท่ากัน
        if len(temp_content) != len(temp_ratings):
            print("จำนวน Content และ Ratings ไม่ตรงกัน เติมค่า 'none'")
            # เติมค่า "none" ให้ข้อมูลที่ขาดหาย
            while len(temp_content) > len(temp_ratings):
                temp_ratings.append("none")
            while len(temp_ratings) > len(temp_content):
                temp_content.append("none")

        # เพิ่มข้อมูลเข้าในรายการหลัก
        all_content_list.extend(temp_content)
        ratings.extend(temp_ratings)
        all_name_list.extend(temp_names)
        date_list.extend(temp_dates)
        like_list.extend(temp_likes)

        # สร้าง DataFrame จากข้อมูลทั้งหมด
        df_content = pd.DataFrame({
            'Content': all_content_list,
            'Rating': ratings,
            'Name': all_name_list,
            'Date': date_list,
            'Like': like_list
        })
        print(df_content)
        
        # คลิกปุ่ม Next
        nextButton = driver.find_element(By.XPATH, '/html/body/div[5]/div/div[10]/div[1]/div[2]/div/div/div/div[3]/div[2]/div/button[2]')
        nextButton.click()

        # ดึงข้อมูล HTML ปัจจุบันจาก Selenium
        data = driver.page_source
        soup = bs4.BeautifulSoup(data)

        # รอให้หน้าโหลดข้อมูลใหม่ก่อนเริ่ม Loop ใหม่
        time.sleep(5)  # รอ 5 วินาที (หรือปรับเวลาตามความเหมาะสม)

    except Exception as e:
        print("เกิดข้อผิดพลาด:", e)
        break  # หยุด Loop หากเกิดข้อผิดพลาด เช่น ไม่มีปุ่มถัดไป

# # บันทึกลงไฟล์ Excel
# df_content.to_excel('content_ratings_filtered.xlsx', index=False)
# print("บันทึกข้อมูลเรียบร้อยใน content_ratings_filtered.xlsx")
# Out:
#                                              Content  Rating         Name  \
# 0  แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2  สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3  สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4  คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
#
#           Date Like
# 0  10 Mar 2023    0
# 1  10 Mar 2023    1
# 2  09 Mar 2023    0
# 3  08 Mar 2023    0
# 4  06 Mar 2023    0
#                                              Content  Rating         Name  \
# 0  แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2  สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3  สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4  คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# 5  คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5     ปีศาจ ใ.
# 6  แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5        ฐ***.
# 7  ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5        บ***ร
# 8  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5      Ninz C.
# 9  ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5     ladda R.
#
#           Date Like
# 0  10 Mar 2023    0
# 1  10 Mar 2023    1
# 2  09 Mar 2023    0
# 3  08 Mar 2023    0
# 4  06 Mar 2023    0
# 5  06 Mar 2023    0
# 6  07 Mar 2023    0
# 7  05 Mar 2023    0
# 8  10 Mar 2023    2
# 9  07 Sep 2022    1
#                                               Content  Rating         Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# 5   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5     ปีศาจ ใ.
# 6   แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5        ฐ***.
# 7   ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5        บ***ร
# 8   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5      Ninz C.
# 9   ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5     ladda R.
# 10  คุณภาพสินค้าดีมาก ความคุ้มค่าดีมาก ร้านบริการด...       5        P***.
# 11  แพ็คดีมากค่ะ ขนมไม่มีแตกเลย  ขนมก็อร่อยชอบมากเ...       5    Pompam L.
# 12  ได้ของไวมาก ๆ ค่ะ ชอบมากค่ะ ร้านค้าก็ส่งเร็วๆ ...       5        F***.
# 13  ราคาถูกส่งเร็วได้ชิมแล้วอร่อยมากค่ะ ไว้มีโอกาส...       5   พิชญาภา ว.
# 14    อร่อยค่า ใส้เยอะ ชอบมากๆ จัดส่งรวดเร็ว แพคดีมาก       5     Kaweewan
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# 5   06 Mar 2023    0
# 6   07 Mar 2023    0
# 7   05 Mar 2023    0
# 8   10 Mar 2023    2
# 9   07 Sep 2022    1
# 10  25 Jul 2022    0
# 11  07 Jan 2022    1
# 12  13 Dec 2021    1
# 13  01 Dec 2021    0
# 14  29 Nov 2021    0
#                                               Content  Rating         Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# 5   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5     ปีศาจ ใ.
# 6   แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5        ฐ***.
# 7   ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5        บ***ร
# 8   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5      Ninz C.
# 9   ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5     ladda R.
# 10  คุณภาพสินค้าดีมาก ความคุ้มค่าดีมาก ร้านบริการด...       5        P***.
# 11  แพ็คดีมากค่ะ ขนมไม่มีแตกเลย  ขนมก็อร่อยชอบมากเ...       5    Pompam L.
# 12  ได้ของไวมาก ๆ ค่ะ ชอบมากค่ะ ร้านค้าก็ส่งเร็วๆ ...       5        F***.
# 13  ราคาถูกส่งเร็วได้ชิมแล้วอร่อยมากค่ะ ไว้มีโอกาส...       5   พิชญาภา ว.
# 14    อร่อยค่า ใส้เยอะ ชอบมากๆ จัดส่งรวดเร็ว แพคดีมาก       5     Kaweewan
# 15          ขนมน่าทานมากอร่อยด้วยนี่สั่งรอบสองแล้วจ้า       5        0***3
# 16  📦Packaging:very well packed,goods a wrapped in...       5    Stuart D.
# 17  💰ราคา:ขนาด รสชาติ ของขนมสมกับราคาค่ะ\n 📦บรรจุภ...       5        8***2
# 18  เปลือกมีเนยและเป็นขุย, ความอร่อยที่ละลายในปาก!...       5        ร***.
# 19  อร่อยมาก!, ทาร์ตที่อร่อยและครีมมี่!, อร่อยมาก!...       5        0***4
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# 5   06 Mar 2023    0
# 6   07 Mar 2023    0
# 7   05 Mar 2023    0
# 8   10 Mar 2023    2
# 9   07 Sep 2022    1
# 10  25 Jul 2022    0
# 11  07 Jan 2022    1
# 12  13 Dec 2021    1
# 13  01 Dec 2021    0
# 14  29 Nov 2021    0
# 15  27 Nov 2021    0
# 16   6 days ago    2
# 17   7 days ago    0
# 18  2 hours ago    0
# 19  2 weeks ago    2
#                                               Content  Rating           Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5          i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5        Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5      เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5          W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5    แสงสว่าง ใ.
# 5   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5       ปีศาจ ใ.
# 6   แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5          ฐ***.
# 7   ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5          บ***ร
# 8   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 9   ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5       ladda R.
# 10  คุณภาพสินค้าดีมาก ความคุ้มค่าดีมาก ร้านบริการด...       5          P***.
# 11  แพ็คดีมากค่ะ ขนมไม่มีแตกเลย  ขนมก็อร่อยชอบมากเ...       5      Pompam L.
# 12  ได้ของไวมาก ๆ ค่ะ ชอบมากค่ะ ร้านค้าก็ส่งเร็วๆ ...       5          F***.
# 13  ราคาถูกส่งเร็วได้ชิมแล้วอร่อยมากค่ะ ไว้มีโอกาส...       5     พิชญาภา ว.
# 14    อร่อยค่า ใส้เยอะ ชอบมากๆ จัดส่งรวดเร็ว แพคดีมาก       5       Kaweewan
# 15          ขนมน่าทานมากอร่อยด้วยนี่สั่งรอบสองแล้วจ้า       5          0***3
# 16  📦Packaging:very well packed,goods a wrapped in...       5      Stuart D.
# 17  💰ราคา:ขนาด รสชาติ ของขนมสมกับราคาค่ะ\n 📦บรรจุภ...       5          8***2
# 18  เปลือกมีเนยและเป็นขุย, ความอร่อยที่ละลายในปาก!...       5          ร***.
# 19  อร่อยมาก!, ทาร์ตที่อร่อยและครีมมี่!, อร่อยมาก!...       5          0***4
# 20  ทางร้านส่งของเร็วมาก สั่งคืนวันที่ 27 กุมภา ขอ...       5  Nattikarn. N.
# 21  คุณค่าของเงิน:  คุ้มค่าาาาาาาาาาาาาาา ราคาไม่เ...       5          R***.
# 22  ทาร์ตอร่อยและเครีมมีความอร่อย!, ความหวานและควา...       5          a***k
# 23  ได้รับสินค้าแล้วค่ะ ชีสทาร์ตสตอเบอรี่ รสชาติอร...       5   จุฬารัตน์ ไ.
# 24  ส่งเร็วดีค่ะ\n 🧀รสชาติ: นุ่มนิ่ม\n 💰ราคา: ถ้าท...       5         Bie I.
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# 5   06 Mar 2023    0
# 6   07 Mar 2023    0
# 7   05 Mar 2023    0
# 8   10 Mar 2023    2
# 9   07 Sep 2022    1
# 10  25 Jul 2022    0
# 11  07 Jan 2022    1
# 12  13 Dec 2021    1
# 13  01 Dec 2021    0
# 14  29 Nov 2021    0
# 15  27 Nov 2021    0
# 16   6 days ago    2
# 17   7 days ago    0
# 18  2 hours ago    0
# 19  2 weeks ago    2
# 20  29 Feb 2024    0
# 21  27 Sep 2023    0
# 22  25 Feb 2024    0
# 23  13 Feb 2024    0
# 24  20 Nov 2024    0
#                                               Content  Rating           Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5          i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5        Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5      เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5          W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5    แสงสว่าง ใ.
# 5   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5       ปีศาจ ใ.
# 6   แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5          ฐ***.
# 7   ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5          บ***ร
# 8   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 9   ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5       ladda R.
# 10  คุณภาพสินค้าดีมาก ความคุ้มค่าดีมาก ร้านบริการด...       5          P***.
# 11  แพ็คดีมากค่ะ ขนมไม่มีแตกเลย  ขนมก็อร่อยชอบมากเ...       5      Pompam L.
# 12  ได้ของไวมาก ๆ ค่ะ ชอบมากค่ะ ร้านค้าก็ส่งเร็วๆ ...       5          F***.
# 13  ราคาถูกส่งเร็วได้ชิมแล้วอร่อยมากค่ะ ไว้มีโอกาส...       5     พิชญาภา ว.
# 14    อร่อยค่า ใส้เยอะ ชอบมากๆ จัดส่งรวดเร็ว แพคดีมาก       5       Kaweewan
# 15          ขนมน่าทานมากอร่อยด้วยนี่สั่งรอบสองแล้วจ้า       5          0***3
# 16  📦Packaging:very well packed,goods a wrapped in...       5      Stuart D.
# 17  💰ราคา:ขนาด รสชาติ ของขนมสมกับราคาค่ะ\n 📦บรรจุภ...       5          8***2
# 18  เปลือกมีเนยและเป็นขุย, ความอร่อยที่ละลายในปาก!...       5          ร***.
# 19  อร่อยมาก!, ทาร์ตที่อร่อยและครีมมี่!, อร่อยมาก!...       5          0***4
# 20  ทางร้านส่งของเร็วมาก สั่งคืนวันที่ 27 กุมภา ขอ...       5  Nattikarn. N.
# 21  คุณค่าของเงิน:  คุ้มค่าาาาาาาาาาาาาาา ราคาไม่เ...       5          R***.
# 22  ทาร์ตอร่อยและเครีมมีความอร่อย!, ความหวานและควา...       5          a***k
# 23  ได้รับสินค้าแล้วค่ะ ชีสทาร์ตสตอเบอรี่ รสชาติอร...       5   จุฬารัตน์ ไ.
# 24  ส่งเร็วดีค่ะ\n 🧀รสชาติ: นุ่มนิ่ม\n 💰ราคา: ถ้าท...       5         Bie I.
# 25  เป็นร้านคุ้กกี้ในดวงใจ สั่งหลายรอบแล้ว อร่อยมา...       5          w***n
# 26  อร่อยสั่งบ่อยแพ็คสินค้ามาดีได้สินค้าครบตรงตามท...       5          ฐ***.
# 27  รสชาติใช้ได้​ครับ​ คล้ายๆ​ ขนมปังสัปปะรด​ ขนส่...       5          พ***.
# 28  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 29  ☑️ได้รับสินค้าเรียบร้อยครบถ้วนค่ะ☑️\nร้านนี้จั...       5          j***r
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# 5   06 Mar 2023    0
# 6   07 Mar 2023    0
# 7   05 Mar 2023    0
# 8   10 Mar 2023    2
# 9   07 Sep 2022    1
# 10  25 Jul 2022    0
# 11  07 Jan 2022    1
# 12  13 Dec 2021    1
# 13  01 Dec 2021    0
# 14  29 Nov 2021    0
# 15  27 Nov 2021    0
# 16   6 days ago    2
# 17   7 days ago    0
# 18  2 hours ago    0
# 19  2 weeks ago    2
# 20  29 Feb 2024    0
# 21  27 Sep 2023    0
# 22  25 Feb 2024    0
# 23  13 Feb 2024    0
# 24  20 Nov 2024    0
# 25  17 Aug 2023    0
# 26  28 Feb 2023    0
# 27  03 Mar 2023    0
# 28  01 Mar 2023    1
# 29  06 Mar 2023    0
#                                               Content  Rating           Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5          i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5        Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5      เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5          W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5    แสงสว่าง ใ.
# 5   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5       ปีศาจ ใ.
# 6   แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5          ฐ***.
# 7   ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5          บ***ร
# 8   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 9   ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5       ladda R.
# 10  คุณภาพสินค้าดีมาก ความคุ้มค่าดีมาก ร้านบริการด...       5          P***.
# 11  แพ็คดีมากค่ะ ขนมไม่มีแตกเลย  ขนมก็อร่อยชอบมากเ...       5      Pompam L.
# 12  ได้ของไวมาก ๆ ค่ะ ชอบมากค่ะ ร้านค้าก็ส่งเร็วๆ ...       5          F***.
# 13  ราคาถูกส่งเร็วได้ชิมแล้วอร่อยมากค่ะ ไว้มีโอกาส...       5     พิชญาภา ว.
# 14    อร่อยค่า ใส้เยอะ ชอบมากๆ จัดส่งรวดเร็ว แพคดีมาก       5       Kaweewan
# 15          ขนมน่าทานมากอร่อยด้วยนี่สั่งรอบสองแล้วจ้า       5          0***3
# 16  📦Packaging:very well packed,goods a wrapped in...       5      Stuart D.
# 17  💰ราคา:ขนาด รสชาติ ของขนมสมกับราคาค่ะ\n 📦บรรจุภ...       5          8***2
# 18  เปลือกมีเนยและเป็นขุย, ความอร่อยที่ละลายในปาก!...       5          ร***.
# 19  อร่อยมาก!, ทาร์ตที่อร่อยและครีมมี่!, อร่อยมาก!...       5          0***4
# 20  ทางร้านส่งของเร็วมาก สั่งคืนวันที่ 27 กุมภา ขอ...       5  Nattikarn. N.
# 21  คุณค่าของเงิน:  คุ้มค่าาาาาาาาาาาาาาา ราคาไม่เ...       5          R***.
# 22  ทาร์ตอร่อยและเครีมมีความอร่อย!, ความหวานและควา...       5          a***k
# 23  ได้รับสินค้าแล้วค่ะ ชีสทาร์ตสตอเบอรี่ รสชาติอร...       5   จุฬารัตน์ ไ.
# 24  ส่งเร็วดีค่ะ\n 🧀รสชาติ: นุ่มนิ่ม\n 💰ราคา: ถ้าท...       5         Bie I.
# 25  เป็นร้านคุ้กกี้ในดวงใจ สั่งหลายรอบแล้ว อร่อยมา...       5          w***n
# 26  อร่อยสั่งบ่อยแพ็คสินค้ามาดีได้สินค้าครบตรงตามท...       5          ฐ***.
# 27  รสชาติใช้ได้​ครับ​ คล้ายๆ​ ขนมปังสัปปะรด​ ขนส่...       5          พ***.
# 28  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 29  ☑️ได้รับสินค้าเรียบร้อยครบถ้วนค่ะ☑️\nร้านนี้จั...       5          j***r
# 30  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 31  สั่งซื้อวันที่ 1.1 ได้รับวันที่ 7.1 ร้านใส่กล่...       5            shy
# 32  แต่ มีรอยหนูกัด ร้านแพ๊ดมาดี มากคร้าา หมดแล้ว ...       5          0***9
# 33  อร่อยยยยยย ไส้แน่นมากกกก ผลไม้ฉ่ำ หวานอมเปรี้ย...       5   Punnakorn C.
# 34  ดีมากกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกก...       5          K***.
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# 5   06 Mar 2023    0
# 6   07 Mar 2023    0
# 7   05 Mar 2023    0
# 8   10 Mar 2023    2
# 9   07 Sep 2022    1
# 10  25 Jul 2022    0
# 11  07 Jan 2022    1
# 12  13 Dec 2021    1
# 13  01 Dec 2021    0
# 14  29 Nov 2021    0
# 15  27 Nov 2021    0
# 16   6 days ago    2
# 17   7 days ago    0
# 18  2 hours ago    0
# 19  2 weeks ago    2
# 20  29 Feb 2024    0
# 21  27 Sep 2023    0
# 22  25 Feb 2024    0
# 23  13 Feb 2024    0
# 24  20 Nov 2024    0
# 25  17 Aug 2023    0
# 26  28 Feb 2023    0
# 27  03 Mar 2023    0
# 28  01 Mar 2023    1
# 29  06 Mar 2023    0
# 30  01 Mar 2023    1
# 31  09 Jan 2023    0
# 32  27 Dec 2022    0
# 33  23 Dec 2022    0
# 34  05 Dec 2022    0
#                                               Content  Rating           Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5          i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5        Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5      เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5          W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5    แสงสว่าง ใ.
# 5   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5       ปีศาจ ใ.
# 6   แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5          ฐ***.
# 7   ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5          บ***ร
# 8   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 9   ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5       ladda R.
# 10  คุณภาพสินค้าดีมาก ความคุ้มค่าดีมาก ร้านบริการด...       5          P***.
# 11  แพ็คดีมากค่ะ ขนมไม่มีแตกเลย  ขนมก็อร่อยชอบมากเ...       5      Pompam L.
# 12  ได้ของไวมาก ๆ ค่ะ ชอบมากค่ะ ร้านค้าก็ส่งเร็วๆ ...       5          F***.
# 13  ราคาถูกส่งเร็วได้ชิมแล้วอร่อยมากค่ะ ไว้มีโอกาส...       5     พิชญาภา ว.
# 14    อร่อยค่า ใส้เยอะ ชอบมากๆ จัดส่งรวดเร็ว แพคดีมาก       5       Kaweewan
# 15          ขนมน่าทานมากอร่อยด้วยนี่สั่งรอบสองแล้วจ้า       5          0***3
# 16  📦Packaging:very well packed,goods a wrapped in...       5      Stuart D.
# 17  💰ราคา:ขนาด รสชาติ ของขนมสมกับราคาค่ะ\n 📦บรรจุภ...       5          8***2
# 18  เปลือกมีเนยและเป็นขุย, ความอร่อยที่ละลายในปาก!...       5          ร***.
# 19  อร่อยมาก!, ทาร์ตที่อร่อยและครีมมี่!, อร่อยมาก!...       5          0***4
# 20  ทางร้านส่งของเร็วมาก สั่งคืนวันที่ 27 กุมภา ขอ...       5  Nattikarn. N.
# 21  คุณค่าของเงิน:  คุ้มค่าาาาาาาาาาาาาาา ราคาไม่เ...       5          R***.
# 22  ทาร์ตอร่อยและเครีมมีความอร่อย!, ความหวานและควา...       5          a***k
# 23  ได้รับสินค้าแล้วค่ะ ชีสทาร์ตสตอเบอรี่ รสชาติอร...       5   จุฬารัตน์ ไ.
# 24  ส่งเร็วดีค่ะ\n 🧀รสชาติ: นุ่มนิ่ม\n 💰ราคา: ถ้าท...       5         Bie I.
# 25  เป็นร้านคุ้กกี้ในดวงใจ สั่งหลายรอบแล้ว อร่อยมา...       5          w***n
# 26  อร่อยสั่งบ่อยแพ็คสินค้ามาดีได้สินค้าครบตรงตามท...       5          ฐ***.
# 27  รสชาติใช้ได้​ครับ​ คล้ายๆ​ ขนมปังสัปปะรด​ ขนส่...       5          พ***.
# 28  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 29  ☑️ได้รับสินค้าเรียบร้อยครบถ้วนค่ะ☑️\nร้านนี้จั...       5          j***r
# 30  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 31  สั่งซื้อวันที่ 1.1 ได้รับวันที่ 7.1 ร้านใส่กล่...       5            shy
# 32  แต่ มีรอยหนูกัด ร้านแพ๊ดมาดี มากคร้าา หมดแล้ว ...       5          0***9
# 33  อร่อยยยยยย ไส้แน่นมากกกก ผลไม้ฉ่ำ หวานอมเปรี้ย...       5   Punnakorn C.
# 34  ดีมากกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกก...       5          K***.
# 35  กดสั่ง 3พย. ได้รับ 8พย. ขนมต้องรอทำ จัดส่งไวจา...       5          อ***น
# 36  อร่อยมาก ราคาถูกอร่อยมาก ราคาถูกอร่อยมาก ราคาถ...       5          0***7
# 37  ห่อมาดีมากเลยค่ะ​ ขนมอร่อยเพิ่งลองสั่งครั้งแรก...       5          8***4
# 38  แพ็คสินค้ามาดีมากสั่งหลายรอบแล้ว ดีที่สุด ราคา...       5          M***.
# 39  ชีสทาร์ตสตรอเบอรี่หอมหวานจับใจ ลองเลย แล้วจะติดใจ       5          J***.
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# 5   06 Mar 2023    0
# 6   07 Mar 2023    0
# 7   05 Mar 2023    0
# 8   10 Mar 2023    2
# 9   07 Sep 2022    1
# 10  25 Jul 2022    0
# 11  07 Jan 2022    1
# 12  13 Dec 2021    1
# 13  01 Dec 2021    0
# 14  29 Nov 2021    0
# 15  27 Nov 2021    0
# 16   6 days ago    2
# 17   7 days ago    0
# 18  2 hours ago    0
# 19  2 weeks ago    2
# 20  29 Feb 2024    0
# 21  27 Sep 2023    0
# 22  25 Feb 2024    0
# 23  13 Feb 2024    0
# 24  20 Nov 2024    0
# 25  17 Aug 2023    0
# 26  28 Feb 2023    0
# 27  03 Mar 2023    0
# 28  01 Mar 2023    1
# 29  06 Mar 2023    0
# 30  01 Mar 2023    1
# 31  09 Jan 2023    0
# 32  27 Dec 2022    0
# 33  23 Dec 2022    0
# 34  05 Dec 2022    0
# 35  09 Nov 2022    4
# 36  07 Oct 2022    0
# 37  06 Jul 2022    0
# 38  12 May 2022    0
# 39  02 May 2022    0
#                                               Content  Rating           Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5          i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5        Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5      เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5          W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5    แสงสว่าง ใ.
# 5   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5       ปีศาจ ใ.
# 6   แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5          ฐ***.
# 7   ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5          บ***ร
# 8   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 9   ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5       ladda R.
# 10  คุณภาพสินค้าดีมาก ความคุ้มค่าดีมาก ร้านบริการด...       5          P***.
# 11  แพ็คดีมากค่ะ ขนมไม่มีแตกเลย  ขนมก็อร่อยชอบมากเ...       5      Pompam L.
# 12  ได้ของไวมาก ๆ ค่ะ ชอบมากค่ะ ร้านค้าก็ส่งเร็วๆ ...       5          F***.
# 13  ราคาถูกส่งเร็วได้ชิมแล้วอร่อยมากค่ะ ไว้มีโอกาส...       5     พิชญาภา ว.
# 14    อร่อยค่า ใส้เยอะ ชอบมากๆ จัดส่งรวดเร็ว แพคดีมาก       5       Kaweewan
# 15          ขนมน่าทานมากอร่อยด้วยนี่สั่งรอบสองแล้วจ้า       5          0***3
# 16  📦Packaging:very well packed,goods a wrapped in...       5      Stuart D.
# 17  💰ราคา:ขนาด รสชาติ ของขนมสมกับราคาค่ะ\n 📦บรรจุภ...       5          8***2
# 18  เปลือกมีเนยและเป็นขุย, ความอร่อยที่ละลายในปาก!...       5          ร***.
# 19  อร่อยมาก!, ทาร์ตที่อร่อยและครีมมี่!, อร่อยมาก!...       5          0***4
# 20  ทางร้านส่งของเร็วมาก สั่งคืนวันที่ 27 กุมภา ขอ...       5  Nattikarn. N.
# 21  คุณค่าของเงิน:  คุ้มค่าาาาาาาาาาาาาาา ราคาไม่เ...       5          R***.
# 22  ทาร์ตอร่อยและเครีมมีความอร่อย!, ความหวานและควา...       5          a***k
# 23  ได้รับสินค้าแล้วค่ะ ชีสทาร์ตสตอเบอรี่ รสชาติอร...       5   จุฬารัตน์ ไ.
# 24  ส่งเร็วดีค่ะ\n 🧀รสชาติ: นุ่มนิ่ม\n 💰ราคา: ถ้าท...       5         Bie I.
# 25  เป็นร้านคุ้กกี้ในดวงใจ สั่งหลายรอบแล้ว อร่อยมา...       5          w***n
# 26  อร่อยสั่งบ่อยแพ็คสินค้ามาดีได้สินค้าครบตรงตามท...       5          ฐ***.
# 27  รสชาติใช้ได้​ครับ​ คล้ายๆ​ ขนมปังสัปปะรด​ ขนส่...       5          พ***.
# 28  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 29  ☑️ได้รับสินค้าเรียบร้อยครบถ้วนค่ะ☑️\nร้านนี้จั...       5          j***r
# 30  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 31  สั่งซื้อวันที่ 1.1 ได้รับวันที่ 7.1 ร้านใส่กล่...       5            shy
# 32  แต่ มีรอยหนูกัด ร้านแพ๊ดมาดี มากคร้าา หมดแล้ว ...       5          0***9
# 33  อร่อยยยยยย ไส้แน่นมากกกก ผลไม้ฉ่ำ หวานอมเปรี้ย...       5   Punnakorn C.
# 34  ดีมากกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกก...       5          K***.
# 35  กดสั่ง 3พย. ได้รับ 8พย. ขนมต้องรอทำ จัดส่งไวจา...       5          อ***น
# 36  อร่อยมาก ราคาถูกอร่อยมาก ราคาถูกอร่อยมาก ราคาถ...       5          0***7
# 37  ห่อมาดีมากเลยค่ะ​ ขนมอร่อยเพิ่งลองสั่งครั้งแรก...       5          8***4
# 38  แพ็คสินค้ามาดีมากสั่งหลายรอบแล้ว ดีที่สุด ราคา...       5          M***.
# 39  ชีสทาร์ตสตรอเบอรี่หอมหวานจับใจ ลองเลย แล้วจะติดใจ       5          J***.
# 40    ชีสทาร์ต อร่อยมากค่ะ ขนมสดใส จัดส่งรวดเร็วทันใจ       5          แ***.
# 41  สินค้าถูกต้องตรงปก จำนวนครบถ้วนตรงตามที่สั่ง ส...       5          M***e
# 42  สินค้าถูกต้องตรงปก หน้าตาดูดีใช้ได้เลย ยังไม่ไ...       5          M***e
# 43  ขนมได้ตามที่สั้ง คุณภาพคุ้มค่า คุ้มราคา อร่อยม...       5         Pop T.
# 44                  สั่งขนมตอนหิวมันก็จะประมาณนี้นะคะ       5         THE W.
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# 5   06 Mar 2023    0
# 6   07 Mar 2023    0
# 7   05 Mar 2023    0
# 8   10 Mar 2023    2
# 9   07 Sep 2022    1
# 10  25 Jul 2022    0
# 11  07 Jan 2022    1
# 12  13 Dec 2021    1
# 13  01 Dec 2021    0
# 14  29 Nov 2021    0
# 15  27 Nov 2021    0
# 16   6 days ago    2
# 17   7 days ago    0
# 18  2 hours ago    0
# 19  2 weeks ago    2
# 20  29 Feb 2024    0
# 21  27 Sep 2023    0
# 22  25 Feb 2024    0
# 23  13 Feb 2024    0
# 24  20 Nov 2024    0
# 25  17 Aug 2023    0
# 26  28 Feb 2023    0
# 27  03 Mar 2023    0
# 28  01 Mar 2023    1
# 29  06 Mar 2023    0
# 30  01 Mar 2023    1
# 31  09 Jan 2023    0
# 32  27 Dec 2022    0
# 33  23 Dec 2022    0
# 34  05 Dec 2022    0
# 35  09 Nov 2022    4
# 36  07 Oct 2022    0
# 37  06 Jul 2022    0
# 38  12 May 2022    0
# 39  02 May 2022    0
# 40  06 May 2022    0
# 41  18 Apr 2022    0
# 42  06 Apr 2022    0
# 43  31 Mar 2022    0
# 44  05 Apr 2022    0
#                                               Content  Rating           Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5          i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5        Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5      เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5          W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5    แสงสว่าง ใ.
# 5   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5       ปีศาจ ใ.
# 6   แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5          ฐ***.
# 7   ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5          บ***ร
# 8   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 9   ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5       ladda R.
# 10  คุณภาพสินค้าดีมาก ความคุ้มค่าดีมาก ร้านบริการด...       5          P***.
# 11  แพ็คดีมากค่ะ ขนมไม่มีแตกเลย  ขนมก็อร่อยชอบมากเ...       5      Pompam L.
# 12  ได้ของไวมาก ๆ ค่ะ ชอบมากค่ะ ร้านค้าก็ส่งเร็วๆ ...       5          F***.
# 13  ราคาถูกส่งเร็วได้ชิมแล้วอร่อยมากค่ะ ไว้มีโอกาส...       5     พิชญาภา ว.
# 14    อร่อยค่า ใส้เยอะ ชอบมากๆ จัดส่งรวดเร็ว แพคดีมาก       5       Kaweewan
# 15          ขนมน่าทานมากอร่อยด้วยนี่สั่งรอบสองแล้วจ้า       5          0***3
# 16  📦Packaging:very well packed,goods a wrapped in...       5      Stuart D.
# 17  💰ราคา:ขนาด รสชาติ ของขนมสมกับราคาค่ะ\n 📦บรรจุภ...       5          8***2
# 18  เปลือกมีเนยและเป็นขุย, ความอร่อยที่ละลายในปาก!...       5          ร***.
# 19  อร่อยมาก!, ทาร์ตที่อร่อยและครีมมี่!, อร่อยมาก!...       5          0***4
# 20  ทางร้านส่งของเร็วมาก สั่งคืนวันที่ 27 กุมภา ขอ...       5  Nattikarn. N.
# 21  คุณค่าของเงิน:  คุ้มค่าาาาาาาาาาาาาาา ราคาไม่เ...       5          R***.
# 22  ทาร์ตอร่อยและเครีมมีความอร่อย!, ความหวานและควา...       5          a***k
# 23  ได้รับสินค้าแล้วค่ะ ชีสทาร์ตสตอเบอรี่ รสชาติอร...       5   จุฬารัตน์ ไ.
# 24  ส่งเร็วดีค่ะ\n 🧀รสชาติ: นุ่มนิ่ม\n 💰ราคา: ถ้าท...       5         Bie I.
# 25  เป็นร้านคุ้กกี้ในดวงใจ สั่งหลายรอบแล้ว อร่อยมา...       5          w***n
# 26  อร่อยสั่งบ่อยแพ็คสินค้ามาดีได้สินค้าครบตรงตามท...       5          ฐ***.
# 27  รสชาติใช้ได้​ครับ​ คล้ายๆ​ ขนมปังสัปปะรด​ ขนส่...       5          พ***.
# 28  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 29  ☑️ได้รับสินค้าเรียบร้อยครบถ้วนค่ะ☑️\nร้านนี้จั...       5          j***r
# 30  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 31  สั่งซื้อวันที่ 1.1 ได้รับวันที่ 7.1 ร้านใส่กล่...       5            shy
# 32  แต่ มีรอยหนูกัด ร้านแพ๊ดมาดี มากคร้าา หมดแล้ว ...       5          0***9
# 33  อร่อยยยยยย ไส้แน่นมากกกก ผลไม้ฉ่ำ หวานอมเปรี้ย...       5   Punnakorn C.
# 34  ดีมากกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกก...       5          K***.
# 35  กดสั่ง 3พย. ได้รับ 8พย. ขนมต้องรอทำ จัดส่งไวจา...       5          อ***น
# 36  อร่อยมาก ราคาถูกอร่อยมาก ราคาถูกอร่อยมาก ราคาถ...       5          0***7
# 37  ห่อมาดีมากเลยค่ะ​ ขนมอร่อยเพิ่งลองสั่งครั้งแรก...       5          8***4
# 38  แพ็คสินค้ามาดีมากสั่งหลายรอบแล้ว ดีที่สุด ราคา...       5          M***.
# 39  ชีสทาร์ตสตรอเบอรี่หอมหวานจับใจ ลองเลย แล้วจะติดใจ       5          J***.
# 40    ชีสทาร์ต อร่อยมากค่ะ ขนมสดใส จัดส่งรวดเร็วทันใจ       5          แ***.
# 41  สินค้าถูกต้องตรงปก จำนวนครบถ้วนตรงตามที่สั่ง ส...       5          M***e
# 42  สินค้าถูกต้องตรงปก หน้าตาดูดีใช้ได้เลย ยังไม่ไ...       5          M***e
# 43  ขนมได้ตามที่สั้ง คุณภาพคุ้มค่า คุ้มราคา อร่อยม...       5         Pop T.
# 44                  สั่งขนมตอนหิวมันก็จะประมาณนี้นะคะ       5         THE W.
# 45      ขนส่งตามเวลา แพกเก็ตน่ารัก สะอาด ห่อมาอย่างดี       5          P***.
# 46  ร้านค้าขายสินค้าคุณภาพดีราคาไม่แพงสั่งร้านนี้3...       5     จุฑามาศ ล.
# 47  ชีสทาร์ตสตรอเบอรี่ อร่อยหอม รสชาตถูกใจ ทางร้าน...       5        KooK R.
# 48  ของอร่อยสำหรับคนรักสตรอเบอร์รี่, สมดุลที่สมบูร...       5     Anchana T.
# 49  ได้รับสินค้าครบถ้วนถูกต้องในสภาพสมบูรณ์เรียบร้...       5  Starlight0129
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# 5   06 Mar 2023    0
# 6   07 Mar 2023    0
# 7   05 Mar 2023    0
# 8   10 Mar 2023    2
# 9   07 Sep 2022    1
# 10  25 Jul 2022    0
# 11  07 Jan 2022    1
# 12  13 Dec 2021    1
# 13  01 Dec 2021    0
# 14  29 Nov 2021    0
# 15  27 Nov 2021    0
# 16   6 days ago    2
# 17   7 days ago    0
# 18  2 hours ago    0
# 19  2 weeks ago    2
# 20  29 Feb 2024    0
# 21  27 Sep 2023    0
# 22  25 Feb 2024    0
# 23  13 Feb 2024    0
# 24  20 Nov 2024    0
# 25  17 Aug 2023    0
# 26  28 Feb 2023    0
# 27  03 Mar 2023    0
# 28  01 Mar 2023    1
# 29  06 Mar 2023    0
# 30  01 Mar 2023    1
# 31  09 Jan 2023    0
# 32  27 Dec 2022    0
# 33  23 Dec 2022    0
# 34  05 Dec 2022    0
# 35  09 Nov 2022    4
# 36  07 Oct 2022    0
# 37  06 Jul 2022    0
# 38  12 May 2022    0
# 39  02 May 2022    0
# 40  06 May 2022    0
# 41  18 Apr 2022    0
# 42  06 Apr 2022    0
# 43  31 Mar 2022    0
# 44  05 Apr 2022    0
# 45  02 Mar 2022    0
# 46  18 Feb 2022    0
# 47  07 Oct 2022    0
# 48  11 Nov 2024    2
# 49  12 Jul 2023    0
#                                               Content  Rating           Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5          i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5        Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5      เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5          W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5    แสงสว่าง ใ.
# 5   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5       ปีศาจ ใ.
# 6   แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5          ฐ***.
# 7   ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5          บ***ร
# 8   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 9   ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5       ladda R.
# 10  คุณภาพสินค้าดีมาก ความคุ้มค่าดีมาก ร้านบริการด...       5          P***.
# 11  แพ็คดีมากค่ะ ขนมไม่มีแตกเลย  ขนมก็อร่อยชอบมากเ...       5      Pompam L.
# 12  ได้ของไวมาก ๆ ค่ะ ชอบมากค่ะ ร้านค้าก็ส่งเร็วๆ ...       5          F***.
# 13  ราคาถูกส่งเร็วได้ชิมแล้วอร่อยมากค่ะ ไว้มีโอกาส...       5     พิชญาภา ว.
# 14    อร่อยค่า ใส้เยอะ ชอบมากๆ จัดส่งรวดเร็ว แพคดีมาก       5       Kaweewan
# 15          ขนมน่าทานมากอร่อยด้วยนี่สั่งรอบสองแล้วจ้า       5          0***3
# 16  📦Packaging:very well packed,goods a wrapped in...       5      Stuart D.
# 17  💰ราคา:ขนาด รสชาติ ของขนมสมกับราคาค่ะ\n 📦บรรจุภ...       5          8***2
# 18  เปลือกมีเนยและเป็นขุย, ความอร่อยที่ละลายในปาก!...       5          ร***.
# 19  อร่อยมาก!, ทาร์ตที่อร่อยและครีมมี่!, อร่อยมาก!...       5          0***4
# 20  ทางร้านส่งของเร็วมาก สั่งคืนวันที่ 27 กุมภา ขอ...       5  Nattikarn. N.
# 21  คุณค่าของเงิน:  คุ้มค่าาาาาาาาาาาาาาา ราคาไม่เ...       5          R***.
# 22  ทาร์ตอร่อยและเครีมมีความอร่อย!, ความหวานและควา...       5          a***k
# 23  ได้รับสินค้าแล้วค่ะ ชีสทาร์ตสตอเบอรี่ รสชาติอร...       5   จุฬารัตน์ ไ.
# 24  ส่งเร็วดีค่ะ\n 🧀รสชาติ: นุ่มนิ่ม\n 💰ราคา: ถ้าท...       5         Bie I.
# 25  เป็นร้านคุ้กกี้ในดวงใจ สั่งหลายรอบแล้ว อร่อยมา...       5          w***n
# 26  อร่อยสั่งบ่อยแพ็คสินค้ามาดีได้สินค้าครบตรงตามท...       5          ฐ***.
# 27  รสชาติใช้ได้​ครับ​ คล้ายๆ​ ขนมปังสัปปะรด​ ขนส่...       5          พ***.
# 28  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 29  ☑️ได้รับสินค้าเรียบร้อยครบถ้วนค่ะ☑️\nร้านนี้จั...       5          j***r
# 30  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 31  สั่งซื้อวันที่ 1.1 ได้รับวันที่ 7.1 ร้านใส่กล่...       5            shy
# 32  แต่ มีรอยหนูกัด ร้านแพ๊ดมาดี มากคร้าา หมดแล้ว ...       5          0***9
# 33  อร่อยยยยยย ไส้แน่นมากกกก ผลไม้ฉ่ำ หวานอมเปรี้ย...       5   Punnakorn C.
# 34  ดีมากกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกก...       5          K***.
# 35  กดสั่ง 3พย. ได้รับ 8พย. ขนมต้องรอทำ จัดส่งไวจา...       5          อ***น
# 36  อร่อยมาก ราคาถูกอร่อยมาก ราคาถูกอร่อยมาก ราคาถ...       5          0***7
# 37  ห่อมาดีมากเลยค่ะ​ ขนมอร่อยเพิ่งลองสั่งครั้งแรก...       5          8***4
# 38  แพ็คสินค้ามาดีมากสั่งหลายรอบแล้ว ดีที่สุด ราคา...       5          M***.
# 39  ชีสทาร์ตสตรอเบอรี่หอมหวานจับใจ ลองเลย แล้วจะติดใจ       5          J***.
# 40    ชีสทาร์ต อร่อยมากค่ะ ขนมสดใส จัดส่งรวดเร็วทันใจ       5          แ***.
# 41  สินค้าถูกต้องตรงปก จำนวนครบถ้วนตรงตามที่สั่ง ส...       5          M***e
# 42  สินค้าถูกต้องตรงปก หน้าตาดูดีใช้ได้เลย ยังไม่ไ...       5          M***e
# 43  ขนมได้ตามที่สั้ง คุณภาพคุ้มค่า คุ้มราคา อร่อยม...       5         Pop T.
# 44                  สั่งขนมตอนหิวมันก็จะประมาณนี้นะคะ       5         THE W.
# 45      ขนส่งตามเวลา แพกเก็ตน่ารัก สะอาด ห่อมาอย่างดี       5          P***.
# 46  ร้านค้าขายสินค้าคุณภาพดีราคาไม่แพงสั่งร้านนี้3...       5     จุฑามาศ ล.
# 47  ชีสทาร์ตสตรอเบอรี่ อร่อยหอม รสชาตถูกใจ ทางร้าน...       5        KooK R.
# 48  ของอร่อยสำหรับคนรักสตรอเบอร์รี่, สมดุลที่สมบูร...       5     Anchana T.
# 49  ได้รับสินค้าครบถ้วนถูกต้องในสภาพสมบูรณ์เรียบร้...       5  Starlight0129
# 50  ไม่มีรูปสินค้า เผลอกินไปหมดแล้ว สินค้าอร่อยมาก...       5    Jeerasak J.
# 51  ได้รับ chitas สตอเบอรี่สตอเบอรี่ชีสพาร์ตโฮมเมด...       5  พิชชานันท์ เ.
# 52  อร่อยมาก ส่งไว อยากได้อีก\nดีมากกกกกกดีมากกกกก...       5          b***.
# 53  สมดุลที่สมบูรณ์แบบของความหวานและความเปรี้ยว, เ...       5          N***n
# 54  ไส้ชีสเนื้อนุ่มและเนื้อนวล, อร่อยมาก!, สมดุลที...       5          ป***.
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# 5   06 Mar 2023    0
# 6   07 Mar 2023    0
# 7   05 Mar 2023    0
# 8   10 Mar 2023    2
# 9   07 Sep 2022    1
# 10  25 Jul 2022    0
# 11  07 Jan 2022    1
# 12  13 Dec 2021    1
# 13  01 Dec 2021    0
# 14  29 Nov 2021    0
# 15  27 Nov 2021    0
# 16   6 days ago    2
# 17   7 days ago    0
# 18  2 hours ago    0
# 19  2 weeks ago    2
# 20  29 Feb 2024    0
# 21  27 Sep 2023    0
# 22  25 Feb 2024    0
# 23  13 Feb 2024    0
# 24  20 Nov 2024    0
# 25  17 Aug 2023    0
# 26  28 Feb 2023    0
# 27  03 Mar 2023    0
# 28  01 Mar 2023    1
# 29  06 Mar 2023    0
# 30  01 Mar 2023    1
# 31  09 Jan 2023    0
# 32  27 Dec 2022    0
# 33  23 Dec 2022    0
# 34  05 Dec 2022    0
# 35  09 Nov 2022    4
# 36  07 Oct 2022    0
# 37  06 Jul 2022    0
# 38  12 May 2022    0
# 39  02 May 2022    0
# 40  06 May 2022    0
# 41  18 Apr 2022    0
# 42  06 Apr 2022    0
# 43  31 Mar 2022    0
# 44  05 Apr 2022    0
# 45  02 Mar 2022    0
# 46  18 Feb 2022    0
# 47  07 Oct 2022    0
# 48  11 Nov 2024    2
# 49  12 Jul 2023    0
# 50  28 Jun 2023    0
# 51  10 Jun 2023    0
# 52  09 Jun 2023    0
# 53  27 Oct 2024    0
# 54  25 Oct 2024    0
#                                               Content  Rating           Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5          i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5        Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5      เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5          W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5    แสงสว่าง ใ.
# 5   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5       ปีศาจ ใ.
# 6   แพ็คสินค้ามาดีได้สินค้าครบตรงตามที่สั่งสินค้าด...       5          ฐ***.
# 7   ชีสมาร์คสตรอเบอรี่ สินค้าตรงปก สินค้าคุณภาพทาง...       5          บ***ร
# 8   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 9   ได้รับสินค้าถูกต้องเรียบร้อยดีค่ะทางร้านแพ็คห่...       5       ladda R.
# 10  คุณภาพสินค้าดีมาก ความคุ้มค่าดีมาก ร้านบริการด...       5          P***.
# 11  แพ็คดีมากค่ะ ขนมไม่มีแตกเลย  ขนมก็อร่อยชอบมากเ...       5      Pompam L.
# 12  ได้ของไวมาก ๆ ค่ะ ชอบมากค่ะ ร้านค้าก็ส่งเร็วๆ ...       5          F***.
# 13  ราคาถูกส่งเร็วได้ชิมแล้วอร่อยมากค่ะ ไว้มีโอกาส...       5     พิชญาภา ว.
# 14    อร่อยค่า ใส้เยอะ ชอบมากๆ จัดส่งรวดเร็ว แพคดีมาก       5       Kaweewan
# 15          ขนมน่าทานมากอร่อยด้วยนี่สั่งรอบสองแล้วจ้า       5          0***3
# 16  📦Packaging:very well packed,goods a wrapped in...       5      Stuart D.
# 17  💰ราคา:ขนาด รสชาติ ของขนมสมกับราคาค่ะ\n 📦บรรจุภ...       5          8***2
# 18  เปลือกมีเนยและเป็นขุย, ความอร่อยที่ละลายในปาก!...       5          ร***.
# 19  อร่อยมาก!, ทาร์ตที่อร่อยและครีมมี่!, อร่อยมาก!...       5          0***4
# 20  ทางร้านส่งของเร็วมาก สั่งคืนวันที่ 27 กุมภา ขอ...       5  Nattikarn. N.
# 21  คุณค่าของเงิน:  คุ้มค่าาาาาาาาาาาาาาา ราคาไม่เ...       5          R***.
# 22  ทาร์ตอร่อยและเครีมมีความอร่อย!, ความหวานและควา...       5          a***k
# 23  ได้รับสินค้าแล้วค่ะ ชีสทาร์ตสตอเบอรี่ รสชาติอร...       5   จุฬารัตน์ ไ.
# 24  ส่งเร็วดีค่ะ\n 🧀รสชาติ: นุ่มนิ่ม\n 💰ราคา: ถ้าท...       5         Bie I.
# 25  เป็นร้านคุ้กกี้ในดวงใจ สั่งหลายรอบแล้ว อร่อยมา...       5          w***n
# 26  อร่อยสั่งบ่อยแพ็คสินค้ามาดีได้สินค้าครบตรงตามท...       5          ฐ***.
# 27  รสชาติใช้ได้​ครับ​ คล้ายๆ​ ขนมปังสัปปะรด​ ขนส่...       5          พ***.
# 28  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 29  ☑️ได้รับสินค้าเรียบร้อยครบถ้วนค่ะ☑️\nร้านนี้จั...       5          j***r
# 30  ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม และจั...       5        Ninz C.
# 31  สั่งซื้อวันที่ 1.1 ได้รับวันที่ 7.1 ร้านใส่กล่...       5            shy
# 32  แต่ มีรอยหนูกัด ร้านแพ๊ดมาดี มากคร้าา หมดแล้ว ...       5          0***9
# 33  อร่อยยยยยย ไส้แน่นมากกกก ผลไม้ฉ่ำ หวานอมเปรี้ย...       5   Punnakorn C.
# 34  ดีมากกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกกก...       5          K***.
# 35  กดสั่ง 3พย. ได้รับ 8พย. ขนมต้องรอทำ จัดส่งไวจา...       5          อ***น
# 36  อร่อยมาก ราคาถูกอร่อยมาก ราคาถูกอร่อยมาก ราคาถ...       5          0***7
# 37  ห่อมาดีมากเลยค่ะ​ ขนมอร่อยเพิ่งลองสั่งครั้งแรก...       5          8***4
# 38  แพ็คสินค้ามาดีมากสั่งหลายรอบแล้ว ดีที่สุด ราคา...       5          M***.
# 39  ชีสทาร์ตสตรอเบอรี่หอมหวานจับใจ ลองเลย แล้วจะติดใจ       5          J***.
# 40    ชีสทาร์ต อร่อยมากค่ะ ขนมสดใส จัดส่งรวดเร็วทันใจ       5          แ***.
# 41  สินค้าถูกต้องตรงปก จำนวนครบถ้วนตรงตามที่สั่ง ส...       5          M***e
# 42  สินค้าถูกต้องตรงปก หน้าตาดูดีใช้ได้เลย ยังไม่ไ...       5          M***e
# 43  ขนมได้ตามที่สั้ง คุณภาพคุ้มค่า คุ้มราคา อร่อยม...       5         Pop T.
# 44                  สั่งขนมตอนหิวมันก็จะประมาณนี้นะคะ       5         THE W.
# 45      ขนส่งตามเวลา แพกเก็ตน่ารัก สะอาด ห่อมาอย่างดี       5          P***.
# 46  ร้านค้าขายสินค้าคุณภาพดีราคาไม่แพงสั่งร้านนี้3...       5     จุฑามาศ ล.
# 47  ชีสทาร์ตสตรอเบอรี่ อร่อยหอม รสชาตถูกใจ ทางร้าน...       5        KooK R.
# 48  ของอร่อยสำหรับคนรักสตรอเบอร์รี่, สมดุลที่สมบูร...       5     Anchana T.
# 49  ได้รับสินค้าครบถ้วนถูกต้องในสภาพสมบูรณ์เรียบร้...       5  Starlight0129
# 50  ไม่มีรูปสินค้า เผลอกินไปหมดแล้ว สินค้าอร่อยมาก...       5    Jeerasak J.
# 51  ได้รับ chitas สตอเบอรี่สตอเบอรี่ชีสพาร์ตโฮมเมด...       5  พิชชานันท์ เ.
# 52  อร่อยมาก ส่งไว อยากได้อีก\nดีมากกกกกกดีมากกกกก...       5          b***.
# 53  สมดุลที่สมบูรณ์แบบของความหวานและความเปรี้ยว, เ...       5          N***n
# 54  ไส้ชีสเนื้อนุ่มและเนื้อนวล, อร่อยมาก!, สมดุลที...       5          ป***.
# 55  ดีมากกกกกกดีมากกกกกกดีมากกกกกก \nส่งเร็ว ส่งไว...       5          b***.
# 56  ได้รับสินค้าครบถ้วนถูกต้องตรงตามที่สั่งไปแล้วน...       5          N***m
# 57  ร้านนี้สั่งบ่อยมากถ้ากดทัน 555... คิดดูว่าเป็น...       5          i***.
# 58  อร่อยแท้จริง!, ไส้ชีสเนื้อนุ่มและเนื้อนวล, รสส...       5          ช***.
# 59  ได้รับสินค้าแล้วครับ สินค้ามีความคุ้มค่าดี มีค...       5       เจษฎา ล.
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# 5   06 Mar 2023    0
# 6   07 Mar 2023    0
# 7   05 Mar 2023    0
# 8   10 Mar 2023    2
# 9   07 Sep 2022    1
# 10  25 Jul 2022    0
# 11  07 Jan 2022    1
# 12  13 Dec 2021    1
# 13  01 Dec 2021    0
# 14  29 Nov 2021    0
# 15  27 Nov 2021    0
# 16   6 days ago    2
# 17   7 days ago    0
# 18  2 hours ago    0
# 19  2 weeks ago    2
# 20  29 Feb 2024    0
# 21  27 Sep 2023    0
# 22  25 Feb 2024    0
# 23  13 Feb 2024    0
# 24  20 Nov 2024    0
# 25  17 Aug 2023    0
# 26  28 Feb 2023    0
# 27  03 Mar 2023    0
# 28  01 Mar 2023    1
# 29  06 Mar 2023    0
# 30  01 Mar 2023    1
# 31  09 Jan 2023    0
# 32  27 Dec 2022    0
# 33  23 Dec 2022    0
# 34  05 Dec 2022    0
# 35  09 Nov 2022    4
# 36  07 Oct 2022    0
# 37  06 Jul 2022    0
# 38  12 May 2022    0
# 39  02 May 2022    0
# 40  06 May 2022    0
# 41  18 Apr 2022    0
# 42  06 Apr 2022    0
# 43  31 Mar 2022    0
# 44  05 Apr 2022    0
# 45  02 Mar 2022    0
# 46  18 Feb 2022    0
# 47  07 Oct 2022    0
# 48  11 Nov 2024    2
# 49  12 Jul 2023    0
# 50  28 Jun 2023    0
# 51  10 Jun 2023    0
# 52  09 Jun 2023    0
# 53  27 Oct 2024    0
# 54  25 Oct 2024    0
# 55  29 May 2023    0
# 56  26 May 2023    0
# 57  18 May 2023    0
# 58  08 Jan 2024    0
# 59  26 Apr 2023    0
#                                               Content  Rating         Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                ...     ...          ...
# 60  ยังไมีไเทานแต่ทานบางอย่างรสชาดดีค่ะดูใหม่สะอาด...       5   วันเพ็ญ ท.
# 61  ได้รับสินค้าแล้วค่ะแต่เพิ่งได้มารีวิวทางร้านจั...       5      Ploy T.
# 62  ส่งสินค้ารวดเร็วครับ  สินค้าตรงกับที่แจ้งไว้ แ...       5        j***e
# 63  ได้รับสินค้าเรียบร้อยแล้วครับสินค้าถูกส่งมาในส...       5     ปีศาจ ใ.
# 64  ได้รับสินค้าแล้วครับ สินค้ามีความคุ้มค่าดี มีค...       5     เจษฎา ล.
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# ..          ...  ...
# 60  01 May 2023    0
# 61  26 Apr 2023    0
# 62  24 Apr 2023    0
# 63  23 Apr 2023    0
# 64  16 Apr 2023    0
#
# [65 rows x 5 columns]
#                                               Content  Rating         Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                ...     ...          ...
# 65                          ร้านโปรดในlazadaเลยค้าบบบ       5     Khwan R.
# 66  คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# 67  อร่อยมากค่ะที่ร้านอาหารในอำเภอเมืองจังหวัดนครศ...       5     ชยากร แ.
# 68  สินค้าดี​ ราคาไม่แพง​ ซื้อใน​lazada​ สะดวกสบาย...       5        S***y
# 69  ได้รับสินค้าเรียบร้อยแล้วครับสินค้าถูกส่งมาในส...       5     ปีศาจ ใ.
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# ..          ...  ...
# 65  26 Jan 2022    0
# 66  31 Mar 2023    0
# 67  02 Apr 2023    0
# 68  02 Apr 2023    0
# 69  02 Apr 2023    0
#
# [70 rows x 5 columns]
#                                               Content  Rating          Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5         i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5       Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5     เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5         W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5   แสงสว่าง ใ.
# ..                                                ...     ...           ...
# 70  ได้ชีสทาร์ตสตรอเบอรี่เรียบร้อยแล้วค่ะ แฟนลองชิ...       5   musicmewsic
# 71  คุณค่าของเงิน:  คุ้มมมมส ราคาไม่เเพง\n รสชาติ:...       5         R***.
# 72  ได้รับสินค้าแล้วค่ะ สินค้าจัดส่งรวดเร็วมากค่ะ ...       5  จุฬารัตน์ ไ.
# 73  สินค้าจัดส่งเร็วมาก สั่งวันที่ 2 วันที่ 3 ได้ร...       5   nipaporn K.
# 74  ร้านนี้ขนมอร่อยทุกอย่างราคาถูกมากอร่อยมากชอบมา...       5     พรทิวา ใ.
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# ..          ...  ...
# 70  15 Dec 2023    0
# 71  05 Nov 2023    0
# 72  05 Oct 2023    0
# 73  03 Oct 2023    0
# 74  21 Jan 2022    0
#
# [75 rows x 5 columns]
#                                               Content  Rating         Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                ...     ...          ...
# 75          อร่อยมาก แนะนำร้านนี้เลย ไม่ผิดหวังแน่นอน       5        n***i
# 76  ได้รับสินค้าแล้วนะคะทางร้านใช้เวลาจัดส่งค่อนข้...       5      Ploy T.
# 77  อร่อยดีค่ะ ราคาไม่แพง แต่คุณภาพเยี่ยม ร้านส่งข...       5        P***.
# 78  ได้รับสินค้าครบถ้วนเรียบร้อย​จัดส่ง​รวดเร็ว​ขน...       5     พจนา​ ร.
# 79  💰ราคา:  ไม่แพง\n 📦บรรจุภัณฑ์:  ดี\n 🧀รสชาติ:  ...       5        Z***X
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# ..          ...  ...
# 75  19 Jan 2022    0
# 76  23 Mar 2023    0
# 77  05 Mar 2022    0
# 78  15 Jan 2022    0
# 79  08 Oct 2024    0
#
# [80 rows x 5 columns]
#                                               Content  Rating         Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                ...     ...          ...
# 80  สมดุลที่สมบูรณ์แบบของความหวานและความเปรี้ยว, ข...       5     กนกอร ย.
# 81  คุกกี้มินิ และคุกกี้ใหญ่ และขนมอื่นๆ ดูธรรมดา ...       5        0***0
# 82  ขนมอร่อยมากค่ะ ซื้อหลายรอบแล้ว ตัวขนมไม่หวานมา...       5        M***.
# 83  ร้านค้าและขนส่งจัดส่งได้รวดเร็ว สินค้าดูดีมีคุ...       5        B***.
# 84  ไส้ชีสเนื้อนุ่มและเนื้อนวล, ความอร่อยที่ละลายใ...       5        9***3
#
#            Date Like
# 0   10 Mar 2023    0
# 1   10 Mar 2023    1
# 2   09 Mar 2023    0
# 3   08 Mar 2023    0
# 4   06 Mar 2023    0
# ..          ...  ...
# 80  05 Oct 2024    0
# 81  15 Nov 2024    0
# 82  27 Sep 2024    0
# 83  22 Sep 2024    0
# 84  22 Sep 2024    0
#
# [85 rows x 5 columns]
#                                               Content  Rating         Name  \
# 0   แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1   ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2   สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3   สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4   คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ...
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 335  29 Jun 2022    0
# 336  15 Feb 2022    0
# 337  14 Feb 2022    0
# 338  16 Feb 2022    0
# 339  11 Feb 2022    0
#
# [340 rows x 5 columns]
#                                                Content  Rating         Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                 ...     ...          ...
# 340  ขนมอร่อยจัดส่ง​ไว​ราคา​ไม่​แพง​แนะนำ​ร้าน​นี้เ...       5     พจนา​ ร.
# 341        ส่งของไวแพ็คของดีขนมก็อร่อยมากเลยค่ะ👍👍👍👍👍🥰🥰       5        F***.
# 342  ชีสทาร์ตสตรอฯ ได้รับสินค้าแล้ว สั่งหลายอย่างเล...       5   ณัติชฎา จ.
# 343            อร่อยมากค่ะ! เปรี้ยวนิดๆ ตัวทาร์ตอร่อย💖       5        n***t
# 344  บริการดี ขนมน่าทานมากเลย เยี่ยมมากๆค่ะ\nชอบมาก...       5   *******989
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 340  08 Feb 2022    0
# 341  08 Feb 2022    0
# 342  08 Feb 2022    0
# 343  08 Feb 2022    0
# 344  07 Sep 2022    0
#
# [345 rows x 5 columns]
#                                                Content  Rating         Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                 ...     ...          ...
# 345  ชอบมากๆๆๆๆ  ยิ่งมีราคาโปรพิเศษ ยิ่งชอบใหญ่เลย\...       5     บุษบง ว.
# 346  สินค้าตรงตามที่สั่งซื้อค่ะ  การแพ๊คสินค้ามาเรี...       5        ร***.
# 347  ขนมอร่อยมาก ชอบมากค่ะ จัดส่งไว ดีราคาไม่แพงเลย...       5        O***.
# 348  แพ็คมาดีคะ อร่อยมาก หอม มันเนยได้มาตอนลดราคา เ...       5   จันทมณี น.
# 349                หอมชีสและสตรอว์เบอรี่ แป้งนุ่มอร่อย       5      สุภาวดี
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 345  07 Sep 2022    0
# 346  03 Sep 2022    0
# 347  02 Sep 2022    0
# 348  25 Aug 2022    0
# 349  10 Aug 2022    0
#
# [350 rows x 5 columns]
#                                                Content  Rating         Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                 ...     ...          ...
# 350                                       อร่อยมากๆค่ะ       5    ปาณิศา ท.
# 351  สินค้าจัดส่งเร็วมาก ราคาดี อร่อย คุ้ม สั่งอีกแ...       5        s***y
# 352  อร่อย ชอบ จัดโปรโมชันบ่อยๆ น่ะครับ🤪🎊🐸🐸🐸👻🥰🥰🏳️‍🌈...       5        c***.
# 353  อร่อยมาก ชอบรสสตรอเบอรี่มากๆเลย แต่ไม่ใช่สตรเบ...       5        P***p
# 354                            นุ่มมมมร่วนนนนนอร่อยยยย       5   Sujitra T.
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 350  27 Jul 2022    0
# 351  25 Jul 2022    0
# 352  03 Sep 2022    0
# 353  07 Sep 2022    0
# 354  20 Jul 2022    0
#
# [355 rows x 5 columns]
#                                                Content  Rating         Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                 ...     ...          ...
# 355  อร่อย หยุดกินไม่ได้เลยค่าา แป้งหอมๆ แต่ใส้มีแต...       5      Piyarat
# 356  ชีสทาร์ตสตรอเบอรี่​ หอมมาก​ อร่อย​ แพคเกจสวยแย...       5        W***y
# 357                          อร่อยดี ไม่หวานไป ไส้เยอะ       5        ล***.
# 358  Flavour: \nส่งของเร็ว แพ็คมาให้ดี ดี ดีมากกกกก...       5        S***.
# 359  ความหวานและความเปรี้ยวสมดุลเป็นอย่างดี, อร่อยแ...       5        พ***.
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 355  02 Feb 2022    0
# 356  08 Sep 2022    0
# 357  24 Jul 2022    0
# 358  09 Apr 2024    0
# 359  08 Apr 2024    0
#
# [360 rows x 5 columns]
#                                                Content  Rating         Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                 ...     ...          ...
# 360  ไส้ชีสเนื้อนุ่มและเนื้อนวล, ขนมอร่อยสำหรับคนรั...       5        พ***.
# 361        อร่อยคะ ส่งเร็วกว่าปกติ  เตรียมตัวสั่งเพิ่ม       5   นงเยาว์ เ.
# 362               สด​ สะอาด​ อร่อย​ ราคา​ถูก​ ส่งเร็ว​       5        0***6
# 363      ตัวนี้คอ strawberry ห้ามพลาด  ดีงามเกินบรรยาย       5     ชุมพล ม.
# 364  อร่อยมากสั่งมาครั้งที่สองแล้ว แพคเกจดีสวยงามขน...       5        J***v
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 360  08 Apr 2024    0
# 361  01 Feb 2022    0
# 362  26 Jul 2022    0
# 363  25 Jul 2022    0
# 364  24 Apr 2024    0
#
# [365 rows x 5 columns]
#                                                Content  Rating         Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                 ...     ...          ...
# 365  รสสตรอเบอรี่อร่อยมาก!, ความหวานและความเปรี้ยวส...       5     กนกอร ย.
# 366  ส่งเร็วมากกกกกกกกกกกกกกกกกกกก ขนมอร่อยดี หอมๆเ...       5    คิตตี้ พ.
# 367  เนื้อแป้งหอมมันอร่อยตัวไส้หวานมีกลิ่นอ่อนๆ ตัว...       5  วิราภรณ์ แ.
# 368                                        อร่อยมากค่ะ       5   🌜SASITIMA🌛
# 369                    ขนมอร่อยค่ะไม่หวานมาก แพคเก็ตดี       5        S***.
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 365  20 Apr 2024    0
# 366  29 Jan 2022    0
# 367  02 Sep 2022    0
# 368  28 Jan 2022    0
# 369  28 Jan 2022    0
#
# [370 rows x 5 columns]
#                                                Content  Rating           Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5          i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5        Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5      เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5          W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5    แสงสว่าง ใ.
# ..                                                 ...     ...            ...
# 370  แพคมาอย่างดี ขนมไม่มีแตกหรือเสียหาย\nรสชาตขนมอ...       5          น***.
# 371   ซื้อประจำร้านนี้ อร่อยค่ะ แพ็คของมาดี เหมือนเดิม       5          ส***.
# 372  สวัสดรค่ะ ได้บสินค้าเป็นคุ้กกี้เรียบร้อยดีมากๆ...       5     *******667
# 373  สินค้าดีค่ะ จัดส่งถือว่ารวดเร็วดีค่ะ แพคสินค้า...       5          J***9
# 374                          อร่อยมากค่ะ จัดส่งรวดเร็ว       5  Amp.Sasiparpa
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 370  28 Jan 2022    0
# 371  21 Jun 2022    0
# 372  08 May 2024    0
# 373  05 May 2024    0
# 374  26 Jan 2022    0
#
# [375 rows x 5 columns]
#                                                Content  Rating  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5
# ..                                                 ...     ...
# 375                             อร่อยถูกด้วยๆๆๆๆๆๆๆๆๆๆ       5
# 376  เครื่องหมายเป็นเนื้อสัตว์และกรอบ, ขนมอร่อยสำหร...       5
# 377  ส่งเร็วมาก อร่อยมากๆๆๆๆ สั่งหลายครั้งแล้ว และจ...       5
# 378  มาถึงไวมากครับแพ็คมาเป็นอย่างดี ขนม\nไม่มีแตกเ...       5
# 379  ขนมอร่อยจัดส่งไวราคาไม่แพงแนะนำ​ร้าน​นี้เลย​จร...       5
#
#                 Name         Date Like
# 0              i***.  10 Mar 2023    0
# 1            Ninz C.  10 Mar 2023    1
# 2          เกศมณี ว.  09 Mar 2023    0
# 3              W***.  08 Mar 2023    0
# 4        แสงสว่าง ใ.  06 Mar 2023    0
# ..               ...          ...  ...
# 375      Pantavan T.  26 Jan 2022    0
# 376      Nutchaya W.  01 Apr 2024    0
# 377            P***n  02 Apr 2024    0
# 378  K.....Ch.......  29 Mar 2024    0
# 379         พจนา​ ร.  25 Jan 2022    0
#
# [380 rows x 5 columns]
#                                                Content  Rating         Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                 ...     ...          ...
# 380  สั่งเป็นครั้งที่ 2 แล้วค่ะ ขนมรสชาติอร่อยถูกใจ...       5        จ***า
# 381  ตัวขนมอร่อย มีคุณภาพ ราคาเป็นมิตร แพคจัดส่งโอเ...       5        ส***.
# 382                      ชอบแบบชีสทาต หอมนุ่มนัว อร่อย       5        G***k
# 383                         คุณภาพสมราคา จัดส่งตรงเวลา       5        J***t
# 384                 ยังไม่ลองชิม แต่รอของสักพัก ราคาดี       5        P***.
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 380  01 Apr 2024    0
# 381  26 Aug 2022    0
# 382  12 Aug 2022    0
# 383  23 Jan 2022    0
# 384  22 Jan 2022    0
#
# [385 rows x 5 columns]
#                                                Content  Rating         Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                 ...     ...          ...
# 385                 ส่งไว ได้สินค้าตามที่สั่ง อร่อยค่ะ       5        M***.
# 386                            หวานหอมนุ่มละมุน ชอบมาก       5       Gie H.
# 387                          ได้สินค้าครบ ขนมอร่อยครับ       5      WalkerZ
# 388                     สั่งหลายรอบแล้วค่ะ อร่อยมากค่ะ       5      Kung T.
# 389     เต็ม10ไม่หัก​ ชอบที่สุดจากทุกอย่างที่ซื้อมากิน       5        0***0
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 385  22 Jan 2022    0
# 386  21 Jan 2022    0
# 387  21 Jan 2022    0
# 388  21 Jan 2022    0
# 389  21 Jan 2022    0
#
# [390 rows x 5 columns]
#                                                Content  Rating          Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5         i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5       Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5     เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5         W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5   แสงสว่าง ใ.
# ..                                                 ...     ...           ...
# 390  จัดส่งช้าหน่อย✅✅ แต่หน้าตาหน้าทาน ✅✅ แพ็คมาดีม...       5         0***6
# 391               จัดส่งเร็ว แพคมาดี ขนมอร่อย ถูกใจเลย       5  P'Porapob J.
# 392                           แพคดีขนมน่ารักราคาไม่แพง       5         w***t
# 393    ขนมน่าทานทุกอย่างค่ะ ชิ้นพอดีคำ เก็บง่ายด้วยค่ะ       5         B***.
# 394  ขนมอร่อยสำหรับคนรักสตรอเบอรี่, ละลายในปากอร่อย...       5         ****8
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 390  25 Jul 2022    0
# 391  20 Jan 2022    0
# 392  20 Jan 2022    0
# 393  20 Jan 2022    0
# 394  27 Mar 2024    0
#
# [395 rows x 5 columns]
#                                                Content  Rating         Name  \
# 0    แพ็กเกจจิ้งสวยเหมือนขนมจากญี่ปุ่นเลย เสียดายมา...       5        i***.
# 1    ทางร้านแพ็คสินค้ามาเป็นอย่างดีเหมือนเดิม ชีสทา...       5      Ninz C.
# 2    สั่งรอบ2แล้ว ขนมรสชาดดี บราวนี่อร่อย รอบนี้ใช้...       5    เกศมณี ว.
# 3    สินค้าคุณภาพดี ราคาไม่แพง จัดส่งรวดเร็ว ประทับ...       5        W***.
# 4    คุณค่าของเงิน: รสชาติ:ได้รับสินค้าเรียบร้อยแล้...       5  แสงสว่าง ใ.
# ..                                                 ...     ...          ...
# 395  รสสตรอเบอรี่อร่อยมาก!, อร่อยแท้จริง!, ทาร์ตอร่...       5        พ***.
# 396  ความหวานและความเปรี้ยวสมดุลเป็นอย่างดี, ละลายใ...       5  Nutchaya W.
# 397  ไส้ชีสเนื้อนุ่มและเนื้อนวล, ขนมอร่อยสำหรับคนรั...       5       mit R.
# 398  Good Good Good Good Good Good Good Good Good G...       5        9***1
# 399  แพคเกจสวยงาม รสชาติเข้มข้น เหมาะสำหรับเป็นของฝ...       5    กนกพร. แ.
#
#             Date Like
# 0    10 Mar 2023    0
# 1    10 Mar 2023    1
# 2    09 Mar 2023    0
# 3    08 Mar 2023    0
# 4    06 Mar 2023    0
# ..           ...  ...
# 395  24 Mar 2024    0
# 396  22 Mar 2024    0
# 397  21 Mar 2024    0
# 398  22 Mar 2024    0
# 399  19 Jan 2022    0
#
# [400 rows x 5 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 92
#      89     soup = bs4.BeautifulSoup(data)
#      91     # รอให้หน้าโหลดข้อมูลใหม่ก่อนเริ่ม Loop ใหม่
# ---> 92     time.sleep(5)  # รอ 5 วินาที (หรือปรับเวลาตามความเหมาะสม)
#      94 except Exception as e:
#      95     print("เกิดข้อผิดพลาด:", e)
#
# KeyboardInterrupt:

# %%
 # บันทึกลงไฟล์ Excel
df_content.to_excel('content_ratings_filtered2.xlsx', index=False)
print("บันทึกข้อมูลเรียบร้อยใน content_ratings_filtered.xlsx")
# Out:
# บันทึกข้อมูลเรียบร้อยใน content_ratings_filtered.xlsx
