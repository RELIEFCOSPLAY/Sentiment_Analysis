# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import bs4
import pandas as pd

# %%
service = Service(r'C:\Users\User\Desktop\ETLPY\Sentiment_Analysis\nlp\Web_Scraping\chromedriver\chromedriver.exe')
driver = webdriver.Chrome(service=service)

# %%
driver.get('https://th.hotels.com/Hotel-Search?startDate=2024-11-26&endDate=2024-12-10&regionId=6056227&adults=2&amenities=OCEAN_VIEW&destination=Pattaya%2C%20Chonburi%20Province%2C%20Thailand&theme=&userIntent=&semdtl=&useRewards=false&sort=RECOMMENDED')

# %%
driver.execute_script("document.body.style.zoom='100%'")

# %%
#bad_dataSize = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')

# %%
data = driver.page_source

# %%
soup = bs4.BeautifulSoup(data)

# %%
len(soup.find_all('h3',{'class':'uitk-heading uitk-heading-5 overflow-wrap uitk-layout-grid-item uitk-layout-grid-item-has-row-start'}))
# Out:
# 100

# %%
all_hotels_name = soup.find_all('h3',{'class':'uitk-heading uitk-heading-5 overflow-wrap uitk-layout-grid-item uitk-layout-grid-item-has-row-start'})

# %%
all_hotels_name_list = []
for hotels_name in all_hotels_name:
    all_hotels_name_list.append(hotels_name.text)

df_hotels = pd.DataFrame(all_hotels_name_list)
print(df_hotels.head())
# Out:
#                                         0
# 0  ฮอลิเดย์อินน์ พัทยา เครือโรงแรมไอเอชจี
# 1                             อมารี พัทยา
# 2                      ซัมเมอร์เซ็ท พัทยา
# 3                       โอโซ่ นอร์ธ พัทยา
# 4                  โรงแรมเฮอร์มานน์ พัทยา

# %%
len(soup.find_all('div',{'class':'uitk-layout-flex uitk-layout-flex-align-items-center uitk-layout-flex-gap-one'}))
# Out:
# 279

# %%
all_rate = soup.find_all('div',{'class':'uitk-layout-flex uitk-layout-flex-align-items-center uitk-layout-flex-gap-one'})

# %%
for rate in all_rate:
    print(rate.text)
    print()
# Out:
# 9.29.2 เต็ม 10ยอดเยี่ยมยอดเยี่ยม1,052 รีวิว(1,052 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 1,052 รีวิว(1,052 รีวิว)
#
# 8.88.8 เต็ม 10ดีเลิศดีเลิศ1,034 รีวิว(1,034 รีวิว)
#
# ดีเลิศดีเลิศ
#
# 1,034 รีวิว(1,034 รีวิว)
#
# 9.29.2 เต็ม 10ยอดเยี่ยมยอดเยี่ยม429 รีวิว(429 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 429 รีวิว(429 รีวิว)
#
# 9.29.2 เต็ม 10ยอดเยี่ยมยอดเยี่ยม452 รีวิว(452 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 452 รีวิว(452 รีวิว)
#
# 8.28.2 เต็ม 10ดีมากดีมาก95 รีวิว(95 รีวิว)
#
# ดีมากดีมาก
#
# 95 รีวิว(95 รีวิว)
#
# 8.48.4 เต็ม 10ดีมากดีมาก1,031 รีวิว(1,031 รีวิว)
#
# ดีมากดีมาก
#
# 1,031 รีวิว(1,031 รีวิว)
#
# 9.89.8 เต็ม 10ไร้ที่ติไร้ที่ติ109 รีวิว(109 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 109 รีวิว(109 รีวิว)
#
# 9.29.2 เต็ม 10ยอดเยี่ยมยอดเยี่ยม1,052 รีวิว(1,052 รีวิว)
#
# ยอดเยี่ยมยอดเยี่ยม
#
# 1,052 รีวิว(1,052 รีวิว)
#
# 9.49.4 เต็ม 10ไร้ที่ติไร้ที่ติ588 รีวิว(588 รีวิว)
#
# ไร้ที่ติไร้ที่ติ
#
# 588 รีวิว(588 รีวิว)
#
# 8.28.2 เต็ม 10ดีมากดีมาก1,030 รีวิว(1,030 รีวิว)
#
# ดีมากดีมาก
#
# ...

# %%
len(soup.find_all('div',{'class':'uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden'}))
# Out:
# 111

# %%
all_price = soup.find_all('div',{'class':'uitk-text uitk-type-300 uitk-text-default-theme is-visually-hidden'})

# %%
for price in all_price:
    print(price.text)
    print()
# Out:
# เข้าสู่ระบบหรือสร้างบัญชี
#
# ราคาปัจจุบันคือ ฿12,405
#
# ราคาเดิมคือ ฿6,700
#
# ราคาปัจจุบันคือ ฿5,360
#
# ราคาเดิมคือ ฿7,702
#
# ราคาปัจจุบันคือ ฿6,932
#
# ราคาปัจจุบันคือ ฿3,705
#
# ราคาปัจจุบันคือ ฿4,278
#
# ราคาเดิมคือ ฿6,997
#
# ราคาปัจจุบันคือ ฿4,982
#
# ราคาเดิมคือ ฿13,688
#
# ราคาปัจจุบันคือ ฿9,747
#
# ราคาปัจจุบันคือ ฿12,405
#
# ราคาเดิมคือ ฿8,778
#
# ราคาปัจจุบันคือ ฿6,418
#
# ราคาปัจจุบันคือ ฿3,586
#
# ราคาเดิมคือ ฿4,018
#
# ราคาปัจจุบันคือ ฿3,416
#
# ราคาเดิมคือ ฿8,805
#
# ราคาปัจจุบันคือ ฿6,938
#
# ราคาเดิมคือ ฿6,724
#
# ราคาปัจจุบันคือ ฿5,985
#
# ราคาเดิมคือ ฿7,441
#
# ราคาปัจจุบันคือ ฿6,400
#
# ราคาเดิมคือ ฿5,932
#
# ราคาปัจจุบันคือ ฿4,153
#
# ราคาเดิมคือ ฿6,997
#
# ราคาปัจจุบันคือ ฿4,982
#
# ราคาเดิมคือ ฿4,430
#
# ราคาปัจจุบันคือ ฿2,880
#
# ราคาเดิมคือ ฿3,350
#
# ราคาปัจจุบันคือ ฿2,847
#
# ราคาเดิมคือ ฿4,078
#
# ราคาปัจจุบันคือ ฿1,754
#
# ราคาเดิมคือ ฿2,460
#
# ราคาปัจจุบันคือ ฿2,214
#
# ราคาปัจจุบันคือ ฿2,321
#
# ราคาเดิมคือ ฿3,926
#
# ราคาปัจจุบันคือ ฿2,395
#
# ...
